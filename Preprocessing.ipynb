# %% [markdown]
# # Preprocessing
# Authors: Joel Enrique Díaz Villanueva, Fernando Lopez Barbosa
#
# Organization: Universidad de Monterrey
#
# Created: 28 November 2025
#
# ---

# %%
import os, sys
os.chdir("C:/Users/USER/PEF/Terrain-Traversability-Analysis")
sys.path.append(os.getcwd())
import glob
from FeatureHelpers2 import new_df, is_good_frame, find_subdirectories_os
import pandas as pd
import joblib
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Adoquín

# %%
class_name = 'adoquin'

subdirectories = []
subdirectories = find_subdirectories_os(rf'c:\Users\USER\Desktop\Everything\{class_name}')

for subdir in subdirectories:
    df_shape = []
    good_frames = []
    time_stamp = []
    dataframes_dict = {}
    file_names = {} 

    carpeta = rf'c:\Users\USER\Desktop\Everything\{class_name}\{subdir}' # Global folder path
    output_dir = rf'C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\{class_name}' 

    csv_files = glob.glob(os.path.join(carpeta, '**', '*.csv'), recursive=True)

    folder_name = os.path.basename(carpeta.rstrip('\\').rstrip('_'))
    print("="*40)
    print(f"\nFolder Name: {folder_name}")
    print(f"\nFound a total of {len(csv_files)} CSV files in the directory.")

    for i in range(len(csv_files)):
        df = pl.read_csv(csv_files[i], skip_rows=1)
        if is_good_frame(df):
            good_frames.append(i)
            std_val = df['# TIMESTAMP (ns)'].std()
            time_stamp.append([std_val, i])
            df_transformed = new_df(df)
            dataframes_dict[i] = df_transformed
            df_shape.append(df_transformed.shape)
            
            file_names[i] = os.path.basename(csv_files[i])

    print(f"Approved frames: {len(good_frames)}")

    os.makedirs(output_dir, exist_ok=True)

    if good_frames:
        if len(time_stamp) > 0:
            arr = np.array(time_stamp)
            
            if arr.ndim == 1:
                arr = arr.reshape(1, -1)
            
            sorted_arr = arr[arr[:, 0].argsort()[::-1]]
            num_frames = min(10, len(sorted_arr))
            top_10_indices = sorted_arr[:num_frames, 1].astype(int)
            
            top_10_dfs = {idx: dataframes_dict[idx] for idx in top_10_indices if idx in dataframes_dict}
            
            for rank, (idx, df) in enumerate(top_10_dfs.items(), 1):
                print(f'\n--- # {rank} ---')
                print(f'Original File: {file_names[idx]}')
                print(f'Points: {df.height}')
                
                ''' # Optional Visualization (Makes debugging easier)
                plt.figure(figsize=(6, 6))
                plt.scatter(df["X"], df["Y"], s=1, c=df["Z"], cmap="viridis")
                plt.xlabel("X (m)")
                plt.ylabel("Y (m)")
                plt.title(f"# {rank} - {file_names[idx]}\n(X vs Y) colored by Z")
                plt.colorbar(label="Height Z (m)")
                plt.xlim(-3, 3)
                plt.ylim(0, 3)
                plt.grid(True, alpha=0.3)
                plt.show()
                '''
                
                output_file = f'{output_dir}/{os.path.splitext(file_names[idx])[0]}.csv'
                df.write_csv(output_file)
                print(f'Saved as: {file_names[idx]}.csv')
            
            print(f"Total: {len(top_10_dfs)} frames saved in {output_dir}")
            print("="*40)
        else:
            print("No timestamp data available to rank frames.")
# Out:
# ========================================
#
# Folder Name: adoquin_atras_de_rectoria
#
# Found a total of 74 CSV files in the directory.
# Approved frames: 50
#
# --- # 1 ---
# Original File: adoquin_atras_de_rectoria_61.csv
# Points: 23336
# Saved as: adoquin_atras_de_rectoria_61.csv.csv
#
# --- # 2 ---
# Original File: adoquin_atras_de_rectoria_2.csv
# Points: 23330
# Saved as: adoquin_atras_de_rectoria_2.csv.csv
#
# --- # 3 ---
# Original File: adoquin_atras_de_rectoria_72.csv
# Points: 23328
# Saved as: adoquin_atras_de_rectoria_72.csv.csv
#
# --- # 4 ---
# Original File: adoquin_atras_de_rectoria_33.csv
# Points: 23327
# Saved as: adoquin_atras_de_rectoria_33.csv.csv
#
# --- # 5 ---
# Original File: adoquin_atras_de_rectoria_15.csv
# Points: 23337
# Saved as: adoquin_atras_de_rectoria_15.csv.csv
#
# --- # 6 ---
# Original File: adoquin_atras_de_rectoria_6.csv
# Points: 23331
# Saved as: adoquin_atras_de_rectoria_6.csv.csv
#
# --- # 7 ---
# Original File: adoquin_atras_de_rectoria_46.csv
# Points: 23333
# Saved as: adoquin_atras_de_rectoria_46.csv.csv
#
# --- # 8 ---
# Original File: adoquin_atras_de_rectoria_48.csv
# Points: 23336
# Saved as: adoquin_atras_de_rectoria_48.csv.csv
#
# --- # 9 ---
# Original File: adoquin_atras_de_rectoria_54.csv
# Points: 23324
# Saved as: adoquin_atras_de_rectoria_54.csv.csv
#
# --- # 10 ---
# Original File: adoquin_atras_de_rectoria_70.csv
# Points: 23335
# Saved as: adoquin_atras_de_rectoria_70.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\adoquin
# ========================================
# ========================================
#
# Folder Name: adoquin_cancha_de_futbol
#
# Found a total of 73 CSV files in the directory.
# Approved frames: 44
#
# --- # 1 ---
# Original File: adoquin_cancha_de_futbol_20.csv
# Points: 20870
# Saved as: adoquin_cancha_de_futbol_20.csv.csv
#
# --- # 2 ---
# Original File: adoquin_cancha_de_futbol_24.csv
# Points: 20867
# Saved as: adoquin_cancha_de_futbol_24.csv.csv
#
# --- # 3 ---
# Original File: adoquin_cancha_de_futbol_35.csv
# Points: 20865
# Saved as: adoquin_cancha_de_futbol_35.csv.csv
#
# --- # 4 ---
# Original File: adoquin_cancha_de_futbol_42.csv
# Points: 20868
# Saved as: adoquin_cancha_de_futbol_42.csv.csv
#
# --- # 5 ---
# Original File: adoquin_cancha_de_futbol_18.csv
# Points: 20877
# Saved as: adoquin_cancha_de_futbol_18.csv.csv
#
# --- # 6 ---
# Original File: adoquin_cancha_de_futbol_27.csv
# Points: 20872
# Saved as: adoquin_cancha_de_futbol_27.csv.csv
#
# --- # 7 ---
# Original File: adoquin_cancha_de_futbol_62.csv
# Points: 20865
# Saved as: adoquin_cancha_de_futbol_62.csv.csv
#
# --- # 8 ---
# Original File: adoquin_cancha_de_futbol_32.csv
# Points: 20871
# Saved as: adoquin_cancha_de_futbol_32.csv.csv
#
# --- # 9 ---
# Original File: adoquin_cancha_de_futbol_2.csv
# Points: 20877
# Saved as: adoquin_cancha_de_futbol_2.csv.csv
#
# --- # 10 ---
# Original File: adoquin_cancha_de_futbol_10.csv
# Points: 20871
# Saved as: adoquin_cancha_de_futbol_10.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\adoquin
# ========================================
# ========================================
#
# Folder Name: adoquin_dropOff
#
# Found a total of 75 CSV files in the directory.
# Approved frames: 57
#
# --- # 1 ---
# Original File: adoquin_dropOff_59.csv
# Points: 21750
# Saved as: adoquin_dropOff_59.csv.csv
#
# --- # 2 ---
# Original File: adoquin_dropOff_45.csv
# Points: 21760
# Saved as: adoquin_dropOff_45.csv.csv
#
# --- # 3 ---
# Original File: adoquin_dropOff_52.csv
# Points: 21746
# Saved as: adoquin_dropOff_52.csv.csv
#
# --- # 4 ---
# Original File: adoquin_dropOff_64.csv
# Points: 21758
# Saved as: adoquin_dropOff_64.csv.csv
#
# --- # 5 ---
# Original File: adoquin_dropOff_42.csv
# Points: 21758
# Saved as: adoquin_dropOff_42.csv.csv
#
# --- # 6 ---
# Original File: adoquin_dropOff_70.csv
# Points: 21746
# Saved as: adoquin_dropOff_70.csv.csv
#
# --- # 7 ---
# Original File: adoquin_dropOff_63.csv
# Points: 21741
# Saved as: adoquin_dropOff_63.csv.csv
#
# --- # 8 ---
# Original File: adoquin_dropOff_66.csv
# Points: 21754
# Saved as: adoquin_dropOff_66.csv.csv
#
# --- # 9 ---
# Original File: adoquin_dropOff_37.csv
# Points: 21757
# Saved as: adoquin_dropOff_37.csv.csv
#
# --- # 10 ---
# Original File: adoquin_dropOff_34.csv
# Points: 21750
# Saved as: adoquin_dropOff_34.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\adoquin
# ========================================
# ========================================
#
# Folder Name: adoquin_dropOff_2
#
# Found a total of 60 CSV files in the directory.
# Approved frames: 37
#
# --- # 1 ---
# Original File: adoquin_dropOff_2_27.csv
# Points: 22645
# Saved as: adoquin_dropOff_2_27.csv.csv
#
# --- # 2 ---
# Original File: adoquin_dropOff_2_46.csv
# Points: 22644
# Saved as: adoquin_dropOff_2_46.csv.csv
#
# --- # 3 ---
# Original File: adoquin_dropOff_2_28.csv
# Points: 22658
# Saved as: adoquin_dropOff_2_28.csv.csv
#
# --- # 4 ---
# Original File: adoquin_dropOff_2_31.csv
# Points: 22645
# Saved as: adoquin_dropOff_2_31.csv.csv
#
# --- # 5 ---
# Original File: adoquin_dropOff_2_55.csv
# Points: 22637
# Saved as: adoquin_dropOff_2_55.csv.csv
#
# --- # 6 ---
# Original File: adoquin_dropOff_2_26.csv
# Points: 22638
# Saved as: adoquin_dropOff_2_26.csv.csv
#
# --- # 7 ---
# Original File: adoquin_dropOff_2_49.csv
# Points: 22646
# Saved as: adoquin_dropOff_2_49.csv.csv
#
# --- # 8 ---
# Original File: adoquin_dropOff_2_36.csv
# Points: 22645
# Saved as: adoquin_dropOff_2_36.csv.csv
#
# --- # 9 ---
# Original File: adoquin_dropOff_2_43.csv
# Points: 22624
# Saved as: adoquin_dropOff_2_43.csv.csv
#
# --- # 10 ---
# Original File: adoquin_dropOff_2_21.csv
# Points: 22643
# Saved as: adoquin_dropOff_2_21.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\adoquin
# ========================================
# ========================================
#
# Folder Name: adoquin_escaleras_pasillocrgs_estacionamiento
#
# Found a total of 72 CSV files in the directory.
# Approved frames: 54
#
# --- # 1 ---
# Original File: adoquin_escaleras_pasillocrgs_estacionamiento_67.csv
# Points: 23151
# Saved as: adoquin_escaleras_pasillocrgs_estacionamiento_67.csv.csv
#
# --- # 2 ---
# Original File: adoquin_escaleras_pasillocrgs_estacionamiento_45.csv
# Points: 23153
# Saved as: adoquin_escaleras_pasillocrgs_estacionamiento_45.csv.csv
#
# --- # 3 ---
# Original File: adoquin_escaleras_pasillocrgs_estacionamiento_5.csv
# Points: 23169
# Saved as: adoquin_escaleras_pasillocrgs_estacionamiento_5.csv.csv
#
# --- # 4 ---
# Original File: adoquin_escaleras_pasillocrgs_estacionamiento_10.csv
# Points: 23157
# Saved as: adoquin_escaleras_pasillocrgs_estacionamiento_10.csv.csv
#
# --- # 5 ---
# Original File: adoquin_escaleras_pasillocrgs_estacionamiento_54.csv
# Points: 23145
# Saved as: adoquin_escaleras_pasillocrgs_estacionamiento_54.csv.csv
#
# --- # 6 ---
# Original File: adoquin_escaleras_pasillocrgs_estacionamiento_25.csv
# Points: 23166
# Saved as: adoquin_escaleras_pasillocrgs_estacionamiento_25.csv.csv
#
# --- # 7 ---
# Original File: adoquin_escaleras_pasillocrgs_estacionamiento_64.csv
# Points: 23145
# Saved as: adoquin_escaleras_pasillocrgs_estacionamiento_64.csv.csv
#
# --- # 8 ---
# Original File: adoquin_escaleras_pasillocrgs_estacionamiento_56.csv
# Points: 23149
# Saved as: adoquin_escaleras_pasillocrgs_estacionamiento_56.csv.csv
#
# --- # 9 ---
# Original File: adoquin_escaleras_pasillocrgs_estacionamiento_16.csv
# Points: 23158
# Saved as: adoquin_escaleras_pasillocrgs_estacionamiento_16.csv.csv
#
# --- # 10 ---
# Original File: adoquin_escaleras_pasillocrgs_estacionamiento_32.csv
# Points: 23155
# Saved as: adoquin_escaleras_pasillocrgs_estacionamiento_32.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\adoquin
# ========================================
# ========================================
#
# Folder Name: adoquin_rectoria_otravez
#
# Found a total of 80 CSV files in the directory.
# Approved frames: 44
#
# --- # 1 ---
# Original File: adoquin_rectoria_otravez_54.csv
# Points: 18943
# Saved as: adoquin_rectoria_otravez_54.csv.csv
#
# --- # 2 ---
# Original File: adoquin_rectoria_otravez_70.csv
# Points: 18945
# Saved as: adoquin_rectoria_otravez_70.csv.csv
#
# --- # 3 ---
# Original File: adoquin_rectoria_otravez_40.csv
# Points: 18959
# Saved as: adoquin_rectoria_otravez_40.csv.csv
#
# --- # 4 ---
# Original File: adoquin_rectoria_otravez_21.csv
# Points: 18954
# Saved as: adoquin_rectoria_otravez_21.csv.csv
#
# --- # 5 ---
# Original File: adoquin_rectoria_otravez_32.csv
# Points: 18948
# Saved as: adoquin_rectoria_otravez_32.csv.csv
#
# --- # 6 ---
# Original File: adoquin_rectoria_otravez_50.csv
# Points: 18942
# Saved as: adoquin_rectoria_otravez_50.csv.csv
#
# --- # 7 ---
# Original File: adoquin_rectoria_otravez_31.csv
# Points: 18952
# Saved as: adoquin_rectoria_otravez_31.csv.csv
#
# --- # 8 ---
# Original File: adoquin_rectoria_otravez_75.csv
# Points: 18941
# Saved as: adoquin_rectoria_otravez_75.csv.csv
#
# --- # 9 ---
# Original File: adoquin_rectoria_otravez_12.csv
# Points: 18944
# Saved as: adoquin_rectoria_otravez_12.csv.csv
#
# --- # 10 ---
# Original File: adoquin_rectoria_otravez_9.csv
# Points: 18947
# Saved as: adoquin_rectoria_otravez_9.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\adoquin
# ========================================
# ========================================
#
# Folder Name: crgs_adoquin_sombra (copy)
#
# Found a total of 67 CSV files in the directory.
# Approved frames: 25
#
# --- # 1 ---
# Original File: crgs_adoquin_35.csv
# Points: 21100
# Saved as: crgs_adoquin_35.csv.csv
#
# --- # 2 ---
# Original File: crgs_adoquin_27.csv
# Points: 21105
# Saved as: crgs_adoquin_27.csv.csv
#
# --- # 3 ---
# Original File: crgs_adoquin_15.csv
# Points: 21100
# Saved as: crgs_adoquin_15.csv.csv
#
# --- # 4 ---
# Original File: crgs_adoquin_12.csv
# Points: 21104
# Saved as: crgs_adoquin_12.csv.csv
#
# --- # 5 ---
# Original File: crgs_adoquin_6.csv
# Points: 21093
# Saved as: crgs_adoquin_6.csv.csv
#
# --- # 6 ---
# Original File: crgs_adoquin_31.csv
# Points: 21098
# Saved as: crgs_adoquin_31.csv.csv
#
# --- # 7 ---
# Original File: crgs_adoquin_53.csv
# Points: 21106
# Saved as: crgs_adoquin_53.csv.csv
#
# --- # 8 ---
# Original File: crgs_adoquin_65.csv
# Points: 21112
# Saved as: crgs_adoquin_65.csv.csv
#
# --- # 9 ---
# Original File: crgs_adoquin_41.csv
# Points: 21106
# Saved as: crgs_adoquin_41.csv.csv
#
# --- # 10 ---
# Original File: crgs_adoquin_39.csv
# Points: 21104
# Saved as: crgs_adoquin_39.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\adoquin
# ========================================
# ========================================
#
# Folder Name: crgs_atras_adoquin
#
# Found a total of 75 CSV files in the directory.
# Approved frames: 47
#
# --- # 1 ---
# Original File: crgs_atras_adoquin_29.csv
# Points: 23099
# Saved as: crgs_atras_adoquin_29.csv.csv
#
# --- # 2 ---
# Original File: crgs_atras_adoquin_2.csv
# Points: 23103
# Saved as: crgs_atras_adoquin_2.csv.csv
#
# --- # 3 ---
# Original File: crgs_atras_adoquin_14.csv
# Points: 23097
# Saved as: crgs_atras_adoquin_14.csv.csv
#
# --- # 4 ---
# Original File: crgs_atras_adoquin_28.csv
# Points: 23097
# Saved as: crgs_atras_adoquin_28.csv.csv
#
# --- # 5 ---
# Original File: crgs_atras_adoquin_5.csv
# Points: 23088
# Saved as: crgs_atras_adoquin_5.csv.csv
#
# --- # 6 ---
# Original File: crgs_atras_adoquin_51.csv
# Points: 23098
# Saved as: crgs_atras_adoquin_51.csv.csv
#
# --- # 7 ---
# Original File: crgs_atras_adoquin_32.csv
# Points: 23100
# Saved as: crgs_atras_adoquin_32.csv.csv
#
# --- # 8 ---
# Original File: crgs_atras_adoquin_6.csv
# Points: 23102
# Saved as: crgs_atras_adoquin_6.csv.csv
#
# --- # 9 ---
# Original File: crgs_atras_adoquin_69.csv
# Points: 23093
# Saved as: crgs_atras_adoquin_69.csv.csv
#
# --- # 10 ---
# Original File: crgs_atras_adoquin_41.csv
# Points: 23107
# Saved as: crgs_atras_adoquin_41.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\adoquin
# ========================================
# ========================================
#
# Folder Name: crgs_atras_adoquin_2_sombra
#
# Found a total of 78 CSV files in the directory.
# Approved frames: 55
#
# --- # 1 ---
# Original File: crgs_atras_adoquin_2_sombra_28.csv
# Points: 22764
# Saved as: crgs_atras_adoquin_2_sombra_28.csv.csv
#
# --- # 2 ---
# Original File: crgs_atras_adoquin_2_sombra_8.csv
# Points: 22760
# Saved as: crgs_atras_adoquin_2_sombra_8.csv.csv
#
# --- # 3 ---
# Original File: crgs_atras_adoquin_2_sombra_42.csv
# Points: 22756
# Saved as: crgs_atras_adoquin_2_sombra_42.csv.csv
#
# --- # 4 ---
# Original File: crgs_atras_adoquin_2_sombra_73.csv
# Points: 22761
# Saved as: crgs_atras_adoquin_2_sombra_73.csv.csv
#
# --- # 5 ---
# Original File: crgs_atras_adoquin_2_sombra_4.csv
# Points: 22760
# Saved as: crgs_atras_adoquin_2_sombra_4.csv.csv
#
# --- # 6 ---
# Original File: crgs_atras_adoquin_2_sombra_11.csv
# Points: 22765
# Saved as: crgs_atras_adoquin_2_sombra_11.csv.csv
#
# --- # 7 ---
# Original File: crgs_atras_adoquin_2_sombra_72.csv
# Points: 22758
# Saved as: crgs_atras_adoquin_2_sombra_72.csv.csv
#
# --- # 8 ---
# Original File: crgs_atras_adoquin_2_sombra_77.csv
# Points: 22756
# Saved as: crgs_atras_adoquin_2_sombra_77.csv.csv
#
# --- # 9 ---
# Original File: crgs_atras_adoquin_2_sombra_41.csv
# Points: 22755
# Saved as: crgs_atras_adoquin_2_sombra_41.csv.csv
#
# --- # 10 ---
# Original File: crgs_atras_adoquin_2_sombra_70.csv
# Points: 22756
# Saved as: crgs_atras_adoquin_2_sombra_70.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\adoquin
# ========================================
# ========================================
#
# Folder Name: crgs_atras_adoquin_3_sombraysol
#
# Found a total of 72 CSV files in the directory.
# Approved frames: 52
#
# --- # 1 ---
# Original File: crgs_atras_adoquin_3_sombraysol_34.csv
# Points: 23323
# Saved as: crgs_atras_adoquin_3_sombraysol_34.csv.csv
#
# --- # 2 ---
# Original File: crgs_atras_adoquin_3_sombraysol_39.csv
# Points: 23320
# Saved as: crgs_atras_adoquin_3_sombraysol_39.csv.csv
#
# --- # 3 ---
# Original File: crgs_atras_adoquin_3_sombraysol_19.csv
# Points: 23313
# Saved as: crgs_atras_adoquin_3_sombraysol_19.csv.csv
#
# --- # 4 ---
# Original File: crgs_atras_adoquin_3_sombraysol_2.csv
# Points: 23322
# Saved as: crgs_atras_adoquin_3_sombraysol_2.csv.csv
#
# --- # 5 ---
# Original File: crgs_atras_adoquin_3_sombraysol_46.csv
# Points: 23322
# Saved as: crgs_atras_adoquin_3_sombraysol_46.csv.csv
#
# --- # 6 ---
# Original File: crgs_atras_adoquin_3_sombraysol_10.csv
# Points: 23317
# Saved as: crgs_atras_adoquin_3_sombraysol_10.csv.csv
#
# --- # 7 ---
# Original File: crgs_atras_adoquin_3_sombraysol_64.csv
# Points: 23324
# Saved as: crgs_atras_adoquin_3_sombraysol_64.csv.csv
#
# --- # 8 ---
# Original File: crgs_atras_adoquin_3_sombraysol_32.csv
# Points: 23325
# Saved as: crgs_atras_adoquin_3_sombraysol_32.csv.csv
#
# --- # 9 ---
# Original File: crgs_atras_adoquin_3_sombraysol_67.csv
# Points: 23322
# Saved as: crgs_atras_adoquin_3_sombraysol_67.csv.csv
#
# --- # 10 ---
# Original File: crgs_atras_adoquin_3_sombraysol_57.csv
# Points: 23320
# Saved as: crgs_atras_adoquin_3_sombraysol_57.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\adoquin
# ========================================

# %% [markdown]
# ## Asfalto

# %%
class_name = 'asfalto'

subdirectories = []
subdirectories = find_subdirectories_os(rf'c:\Users\USER\Desktop\Everything\{class_name}')

for subdir in subdirectories:
    df_shape = []
    good_frames = []
    time_stamp = []
    dataframes_dict = {}
    file_names = {} 

    carpeta = rf'c:\Users\USER\Desktop\Everything\{class_name}\{subdir}'
    output_dir = rf'C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\{class_name}'

    csv_files = glob.glob(os.path.join(carpeta, '**', '*.csv'), recursive=True)

    folder_name = os.path.basename(carpeta.rstrip('\\').rstrip('_'))
    print("="*40)
    print(f"\nFolder Name: {folder_name}")
    print(f"\nFound a total of {len(csv_files)} CSV files in the directory.")

    for i in range(len(csv_files)):
        df = pl.read_csv(csv_files[i], skip_rows=1)
        if is_good_frame(df):
            good_frames.append(i)
            std_val = df['# TIMESTAMP (ns)'].std()
            time_stamp.append([std_val, i])
            df_transformed = new_df(df)
            dataframes_dict[i] = df_transformed
            df_shape.append(df_transformed.shape)
            
            file_names[i] = os.path.basename(csv_files[i])

    print(f"Approved frames: {len(good_frames)}")

    os.makedirs(output_dir, exist_ok=True)

    if good_frames:
        if len(time_stamp) > 0:
            arr = np.array(time_stamp)
            
            if arr.ndim == 1:
                arr = arr.reshape(1, -1)
            
            sorted_arr = arr[arr[:, 0].argsort()[::-1]]
            num_frames = min(10, len(sorted_arr))
            top_10_indices = sorted_arr[:num_frames, 1].astype(int)
            
            top_10_dfs = {idx: dataframes_dict[idx] for idx in top_10_indices if idx in dataframes_dict}
            
            for rank, (idx, df) in enumerate(top_10_dfs.items(), 1):
                print(f'\n--- # {rank} ---')
                print(f'Original File: {file_names[idx]}')
                print(f'Points: {df.height}')
                
                ''' # Optional Visualization (Makes debugging easier)
                plt.figure(figsize=(6, 6))
                plt.scatter(df["X"], df["Y"], s=1, c=df["Z"], cmap="viridis")
                plt.xlabel("X (m)")
                plt.ylabel("Y (m)")
                plt.title(f"# {rank} - {file_names[idx]}\n(X vs Y) colored by Z")
                plt.colorbar(label="Height Z (m)")
                plt.xlim(-3, 3)
                plt.ylim(0, 3)
                plt.grid(True, alpha=0.3)
                plt.show()
                '''
                
                output_file = f'{output_dir}/{os.path.splitext(file_names[idx])[0]}.csv'
                df.write_csv(output_file)
                print(f'Saved as: {file_names[idx]}.csv')
            
            print(f"Total: {len(top_10_dfs)} frames saved in {output_dir}")
            print("="*40)
        else:
            print("No timestamp data available to rank frames.")
# Out:
# ========================================
#
# Folder Name: asfalto_estacionamiento_biblio
#
# Found a total of 75 CSV files in the directory.
# Approved frames: 73
#
# --- # 1 ---
# Original File: asfalto_estacionamiento_biblio_57.csv
# Points: 20964
# Saved as: asfalto_estacionamiento_biblio_57.csv.csv
#
# --- # 2 ---
# Original File: asfalto_estacionamiento_biblio_15.csv
# Points: 20980
# Saved as: asfalto_estacionamiento_biblio_15.csv.csv
#
# --- # 3 ---
# Original File: asfalto_estacionamiento_biblio_28.csv
# Points: 20985
# Saved as: asfalto_estacionamiento_biblio_28.csv.csv
#
# --- # 4 ---
# Original File: asfalto_estacionamiento_biblio_69.csv
# Points: 20954
# Saved as: asfalto_estacionamiento_biblio_69.csv.csv
#
# --- # 5 ---
# Original File: asfalto_estacionamiento_biblio_43.csv
# Points: 20974
# Saved as: asfalto_estacionamiento_biblio_43.csv.csv
#
# --- # 6 ---
# Original File: asfalto_estacionamiento_biblio_39.csv
# Points: 20966
# Saved as: asfalto_estacionamiento_biblio_39.csv.csv
#
# --- # 7 ---
# Original File: asfalto_estacionamiento_biblio_24.csv
# Points: 20977
# Saved as: asfalto_estacionamiento_biblio_24.csv.csv
#
# --- # 8 ---
# Original File: asfalto_estacionamiento_biblio_61.csv
# Points: 20974
# Saved as: asfalto_estacionamiento_biblio_61.csv.csv
#
# --- # 9 ---
# Original File: asfalto_estacionamiento_biblio_31.csv
# Points: 20967
# Saved as: asfalto_estacionamiento_biblio_31.csv.csv
#
# --- # 10 ---
# Original File: asfalto_estacionamiento_biblio_5.csv
# Points: 20985
# Saved as: asfalto_estacionamiento_biblio_5.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\asfalto
# ========================================
# ========================================
#
# Folder Name: asfalto_estacionamiento_biblio_2
#
# Found a total of 75 CSV files in the directory.
# Approved frames: 70
#
# --- # 1 ---
# Original File: asfalto_estacionamiento_biblio_2_31.csv
# Points: 21290
# Saved as: asfalto_estacionamiento_biblio_2_31.csv.csv
#
# --- # 2 ---
# Original File: asfalto_estacionamiento_biblio_2_62.csv
# Points: 21267
# Saved as: asfalto_estacionamiento_biblio_2_62.csv.csv
#
# --- # 3 ---
# Original File: asfalto_estacionamiento_biblio_2_7.csv
# Points: 21265
# Saved as: asfalto_estacionamiento_biblio_2_7.csv.csv
#
# --- # 4 ---
# Original File: asfalto_estacionamiento_biblio_2_3.csv
# Points: 21267
# Saved as: asfalto_estacionamiento_biblio_2_3.csv.csv
#
# --- # 5 ---
# Original File: asfalto_estacionamiento_biblio_2_65.csv
# Points: 21260
# Saved as: asfalto_estacionamiento_biblio_2_65.csv.csv
#
# --- # 6 ---
# Original File: asfalto_estacionamiento_biblio_2_35.csv
# Points: 21271
# Saved as: asfalto_estacionamiento_biblio_2_35.csv.csv
#
# --- # 7 ---
# Original File: asfalto_estacionamiento_biblio_2_25.csv
# Points: 21264
# Saved as: asfalto_estacionamiento_biblio_2_25.csv.csv
#
# --- # 8 ---
# Original File: asfalto_estacionamiento_biblio_2_24.csv
# Points: 21264
# Saved as: asfalto_estacionamiento_biblio_2_24.csv.csv
#
# --- # 9 ---
# Original File: asfalto_estacionamiento_biblio_2_33.csv
# Points: 21273
# Saved as: asfalto_estacionamiento_biblio_2_33.csv.csv
#
# --- # 10 ---
# Original File: asfalto_estacionamiento_biblio_2_29.csv
# Points: 21265
# Saved as: asfalto_estacionamiento_biblio_2_29.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\asfalto
# ========================================
# ========================================
#
# Folder Name: asfalto_estacionamiento_canchafutbol
#
# Found a total of 89 CSV files in the directory.
# Approved frames: 82
#
# --- # 1 ---
# Original File: asfalto_estacionamiento_canchafutbol_49.csv
# Points: 20016
# Saved as: asfalto_estacionamiento_canchafutbol_49.csv.csv
#
# --- # 2 ---
# Original File: asfalto_estacionamiento_canchafutbol_29.csv
# Points: 20034
# Saved as: asfalto_estacionamiento_canchafutbol_29.csv.csv
#
# --- # 3 ---
# Original File: asfalto_estacionamiento_canchafutbol_64.csv
# Points: 20034
# Saved as: asfalto_estacionamiento_canchafutbol_64.csv.csv
#
# --- # 4 ---
# Original File: asfalto_estacionamiento_canchafutbol_38.csv
# Points: 20033
# Saved as: asfalto_estacionamiento_canchafutbol_38.csv.csv
#
# --- # 5 ---
# Original File: asfalto_estacionamiento_canchafutbol_69.csv
# Points: 20018
# Saved as: asfalto_estacionamiento_canchafutbol_69.csv.csv
#
# --- # 6 ---
# Original File: asfalto_estacionamiento_canchafutbol_8.csv
# Points: 20032
# Saved as: asfalto_estacionamiento_canchafutbol_8.csv.csv
#
# --- # 7 ---
# Original File: asfalto_estacionamiento_canchafutbol_22.csv
# Points: 20024
# Saved as: asfalto_estacionamiento_canchafutbol_22.csv.csv
#
# --- # 8 ---
# Original File: asfalto_estacionamiento_canchafutbol_60.csv
# Points: 20035
# Saved as: asfalto_estacionamiento_canchafutbol_60.csv.csv
#
# --- # 9 ---
# Original File: asfalto_estacionamiento_canchafutbol_42.csv
# Points: 20024
# Saved as: asfalto_estacionamiento_canchafutbol_42.csv.csv
#
# --- # 10 ---
# Original File: asfalto_estacionamiento_canchafutbol_55.csv
# Points: 20029
# Saved as: asfalto_estacionamiento_canchafutbol_55.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\asfalto
# ========================================
# ========================================
#
# Folder Name: asfalto_estacionamiento_garajes
#
# Found a total of 74 CSV files in the directory.
# Approved frames: 49
#
# --- # 1 ---
# Original File: asfalto_estacionamiento_garajes_41.csv
# Points: 20964
# Saved as: asfalto_estacionamiento_garajes_41.csv.csv
#
# --- # 2 ---
# Original File: asfalto_estacionamiento_garajes_33.csv
# Points: 20960
# Saved as: asfalto_estacionamiento_garajes_33.csv.csv
#
# --- # 3 ---
# Original File: asfalto_estacionamiento_garajes_57.csv
# Points: 20953
# Saved as: asfalto_estacionamiento_garajes_57.csv.csv
#
# --- # 4 ---
# Original File: asfalto_estacionamiento_garajes_53.csv
# Points: 20961
# Saved as: asfalto_estacionamiento_garajes_53.csv.csv
#
# --- # 5 ---
# Original File: asfalto_estacionamiento_garajes_17.csv
# Points: 20982
# Saved as: asfalto_estacionamiento_garajes_17.csv.csv
#
# --- # 6 ---
# Original File: asfalto_estacionamiento_garajes_40.csv
# Points: 20967
# Saved as: asfalto_estacionamiento_garajes_40.csv.csv
#
# --- # 7 ---
# Original File: asfalto_estacionamiento_garajes_70.csv
# Points: 20958
# Saved as: asfalto_estacionamiento_garajes_70.csv.csv
#
# --- # 8 ---
# Original File: asfalto_estacionamiento_garajes_58.csv
# Points: 20957
# Saved as: asfalto_estacionamiento_garajes_58.csv.csv
#
# --- # 9 ---
# Original File: asfalto_estacionamiento_garajes_28.csv
# Points: 20967
# Saved as: asfalto_estacionamiento_garajes_28.csv.csv
#
# --- # 10 ---
# Original File: asfalto_estacionamiento_garajes_42.csv
# Points: 20965
# Saved as: asfalto_estacionamiento_garajes_42.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\asfalto
# ========================================
# ========================================
#
# Folder Name: asfalto_estacionamiento_profes
#
# Found a total of 75 CSV files in the directory.
# Approved frames: 68
#
# --- # 1 ---
# Original File: asfalto_estacionamiento_profes_56.csv
# Points: 22730
# Saved as: asfalto_estacionamiento_profes_56.csv.csv
#
# --- # 2 ---
# Original File: asfalto_estacionamiento_profes_41.csv
# Points: 22728
# Saved as: asfalto_estacionamiento_profes_41.csv.csv
#
# --- # 3 ---
# Original File: asfalto_estacionamiento_profes_22.csv
# Points: 22734
# Saved as: asfalto_estacionamiento_profes_22.csv.csv
#
# --- # 4 ---
# Original File: asfalto_estacionamiento_profes_5.csv
# Points: 22734
# Saved as: asfalto_estacionamiento_profes_5.csv.csv
#
# --- # 5 ---
# Original File: asfalto_estacionamiento_profes_34.csv
# Points: 22725
# Saved as: asfalto_estacionamiento_profes_34.csv.csv
#
# --- # 6 ---
# Original File: asfalto_estacionamiento_profes_32.csv
# Points: 22720
# Saved as: asfalto_estacionamiento_profes_32.csv.csv
#
# --- # 7 ---
# Original File: asfalto_estacionamiento_profes_11.csv
# Points: 22730
# Saved as: asfalto_estacionamiento_profes_11.csv.csv
#
# --- # 8 ---
# Original File: asfalto_estacionamiento_profes_0.csv
# Points: 22728
# Saved as: asfalto_estacionamiento_profes_0.csv.csv
#
# --- # 9 ---
# Original File: asfalto_estacionamiento_profes_61.csv
# Points: 22733
# Saved as: asfalto_estacionamiento_profes_61.csv.csv
#
# --- # 10 ---
# Original File: asfalto_estacionamiento_profes_9.csv
# Points: 22730
# Saved as: asfalto_estacionamiento_profes_9.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\asfalto
# ========================================
# ========================================
#
# Folder Name: asfalto_estacionamiento_profes_2
#
# Found a total of 74 CSV files in the directory.
# Approved frames: 66
#
# --- # 1 ---
# Original File: asfalto_estacionamiento_profes_2_48.csv
# Points: 23018
# Saved as: asfalto_estacionamiento_profes_2_48.csv.csv
#
# --- # 2 ---
# Original File: asfalto_estacionamiento_profes_2_17.csv
# Points: 23028
# Saved as: asfalto_estacionamiento_profes_2_17.csv.csv
#
# --- # 3 ---
# Original File: asfalto_estacionamiento_profes_2_70.csv
# Points: 23016
# Saved as: asfalto_estacionamiento_profes_2_70.csv.csv
#
# --- # 4 ---
# Original File: asfalto_estacionamiento_profes_2_0.csv
# Points: 23026
# Saved as: asfalto_estacionamiento_profes_2_0.csv.csv
#
# --- # 5 ---
# Original File: asfalto_estacionamiento_profes_2_61.csv
# Points: 23027
# Saved as: asfalto_estacionamiento_profes_2_61.csv.csv
#
# --- # 6 ---
# Original File: asfalto_estacionamiento_profes_2_10.csv
# Points: 23036
# Saved as: asfalto_estacionamiento_profes_2_10.csv.csv
#
# --- # 7 ---
# Original File: asfalto_estacionamiento_profes_2_69.csv
# Points: 23028
# Saved as: asfalto_estacionamiento_profes_2_69.csv.csv
#
# --- # 8 ---
# Original File: asfalto_estacionamiento_profes_2_50.csv
# Points: 23024
# Saved as: asfalto_estacionamiento_profes_2_50.csv.csv
#
# --- # 9 ---
# Original File: asfalto_estacionamiento_profes_2_64.csv
# Points: 23033
# Saved as: asfalto_estacionamiento_profes_2_64.csv.csv
#
# --- # 10 ---
# Original File: asfalto_estacionamiento_profes_2_44.csv
# Points: 23032
# Saved as: asfalto_estacionamiento_profes_2_44.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\asfalto
# ========================================
# ========================================
#
# Folder Name: asfalto_estacionamiento_rectoria_1
#
# Found a total of 76 CSV files in the directory.
# Approved frames: 67
#
# --- # 1 ---
# Original File: asfalto_estacionamiento_rectoria_1_21.csv
# Points: 19107
# Saved as: asfalto_estacionamiento_rectoria_1_21.csv.csv
#
# --- # 2 ---
# Original File: asfalto_estacionamiento_rectoria_1_28.csv
# Points: 19114
# Saved as: asfalto_estacionamiento_rectoria_1_28.csv.csv
#
# --- # 3 ---
# Original File: asfalto_estacionamiento_rectoria_1_65.csv
# Points: 19097
# Saved as: asfalto_estacionamiento_rectoria_1_65.csv.csv
#
# --- # 4 ---
# Original File: asfalto_estacionamiento_rectoria_1_55.csv
# Points: 19105
# Saved as: asfalto_estacionamiento_rectoria_1_55.csv.csv
#
# --- # 5 ---
# Original File: asfalto_estacionamiento_rectoria_1_12.csv
# Points: 19117
# Saved as: asfalto_estacionamiento_rectoria_1_12.csv.csv
#
# --- # 6 ---
# Original File: asfalto_estacionamiento_rectoria_1_9.csv
# Points: 19111
# Saved as: asfalto_estacionamiento_rectoria_1_9.csv.csv
#
# --- # 7 ---
# Original File: asfalto_estacionamiento_rectoria_1_30.csv
# Points: 19112
# Saved as: asfalto_estacionamiento_rectoria_1_30.csv.csv
#
# --- # 8 ---
# Original File: asfalto_estacionamiento_rectoria_1_17.csv
# Points: 19116
# Saved as: asfalto_estacionamiento_rectoria_1_17.csv.csv
#
# --- # 9 ---
# Original File: asfalto_estacionamiento_rectoria_1_15.csv
# Points: 19114
# Saved as: asfalto_estacionamiento_rectoria_1_15.csv.csv
#
# --- # 10 ---
# Original File: asfalto_estacionamiento_rectoria_1_39.csv
# Points: 19120
# Saved as: asfalto_estacionamiento_rectoria_1_39.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\asfalto
# ========================================
# ========================================
#
# Folder Name: asfalto_estacionamiento_rectoria_2
#
# Found a total of 73 CSV files in the directory.
# Approved frames: 64
#
# --- # 1 ---
# Original File: asfalto_estacionamiento_rectoria_2_27.csv
# Points: 23165
# Saved as: asfalto_estacionamiento_rectoria_2_27.csv.csv
#
# --- # 2 ---
# Original File: asfalto_estacionamiento_rectoria_2_36.csv
# Points: 23163
# Saved as: asfalto_estacionamiento_rectoria_2_36.csv.csv
#
# --- # 3 ---
# Original File: asfalto_estacionamiento_rectoria_2_23.csv
# Points: 23160
# Saved as: asfalto_estacionamiento_rectoria_2_23.csv.csv
#
# --- # 4 ---
# Original File: asfalto_estacionamiento_rectoria_2_6.csv
# Points: 23158
# Saved as: asfalto_estacionamiento_rectoria_2_6.csv.csv
#
# --- # 5 ---
# Original File: asfalto_estacionamiento_rectoria_2_40.csv
# Points: 23169
# Saved as: asfalto_estacionamiento_rectoria_2_40.csv.csv
#
# --- # 6 ---
# Original File: asfalto_estacionamiento_rectoria_2_12.csv
# Points: 23171
# Saved as: asfalto_estacionamiento_rectoria_2_12.csv.csv
#
# --- # 7 ---
# Original File: asfalto_estacionamiento_rectoria_2_16.csv
# Points: 23149
# Saved as: asfalto_estacionamiento_rectoria_2_16.csv.csv
#
# --- # 8 ---
# Original File: asfalto_estacionamiento_rectoria_2_63.csv
# Points: 23156
# Saved as: asfalto_estacionamiento_rectoria_2_63.csv.csv
#
# --- # 9 ---
# Original File: asfalto_estacionamiento_rectoria_2_58.csv
# Points: 23161
# Saved as: asfalto_estacionamiento_rectoria_2_58.csv.csv
#
# --- # 10 ---
# Original File: asfalto_estacionamiento_rectoria_2_15.csv
# Points: 23157
# Saved as: asfalto_estacionamiento_rectoria_2_15.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\asfalto
# ========================================
# ========================================
#
# Folder Name: asfalto_rampa_profesores_estacionamiento_sombra
#
# Found a total of 74 CSV files in the directory.
# Approved frames: 38
#
# --- # 1 ---
# Original File: rampa_profes_estacionamiento_1_3.csv
# Points: 22692
# Saved as: rampa_profes_estacionamiento_1_3.csv.csv
#
# --- # 2 ---
# Original File: rampa_profes_estacionamiento_1_16.csv
# Points: 22706
# Saved as: rampa_profes_estacionamiento_1_16.csv.csv
#
# --- # 3 ---
# Original File: rampa_profes_estacionamiento_1_8.csv
# Points: 22696
# Saved as: rampa_profes_estacionamiento_1_8.csv.csv
#
# --- # 4 ---
# Original File: rampa_profes_estacionamiento_1_12.csv
# Points: 22695
# Saved as: rampa_profes_estacionamiento_1_12.csv.csv
#
# --- # 5 ---
# Original File: rampa_profes_estacionamiento_1_5.csv
# Points: 22705
# Saved as: rampa_profes_estacionamiento_1_5.csv.csv
#
# --- # 6 ---
# Original File: rampa_profes_estacionamiento_1_28.csv
# Points: 22688
# Saved as: rampa_profes_estacionamiento_1_28.csv.csv
#
# --- # 7 ---
# Original File: rampa_profes_estacionamiento_1_24.csv
# Points: 22704
# Saved as: rampa_profes_estacionamiento_1_24.csv.csv
#
# --- # 8 ---
# Original File: rampa_profes_estacionamiento_1_70.csv
# Points: 22690
# Saved as: rampa_profes_estacionamiento_1_70.csv.csv
#
# --- # 9 ---
# Original File: rampa_profes_estacionamiento_1_37.csv
# Points: 22703
# Saved as: rampa_profes_estacionamiento_1_37.csv.csv
#
# --- # 10 ---
# Original File: rampa_profes_estacionamiento_1_22.csv
# Points: 22702
# Saved as: rampa_profes_estacionamiento_1_22.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\asfalto
# ========================================
# ========================================
#
# Folder Name: asfalto_rampa_profesor_estacionamiento_2_sombra
#
# Found a total of 73 CSV files in the directory.
# Approved frames: 40
#
# --- # 1 ---
# Original File: rampa_profes_estacionamiento_2_2.csv
# Points: 22083
# Saved as: rampa_profes_estacionamiento_2_2.csv.csv
#
# --- # 2 ---
# Original File: rampa_profes_estacionamiento_2_72.csv
# Points: 22069
# Saved as: rampa_profes_estacionamiento_2_72.csv.csv
#
# --- # 3 ---
# Original File: rampa_profes_estacionamiento_2_31.csv
# Points: 22064
# Saved as: rampa_profes_estacionamiento_2_31.csv.csv
#
# --- # 4 ---
# Original File: rampa_profes_estacionamiento_2_24.csv
# Points: 22084
# Saved as: rampa_profes_estacionamiento_2_24.csv.csv
#
# --- # 5 ---
# Original File: rampa_profes_estacionamiento_2_46.csv
# Points: 22081
# Saved as: rampa_profes_estacionamiento_2_46.csv.csv
#
# --- # 6 ---
# Original File: rampa_profes_estacionamiento_2_51.csv
# Points: 22064
# Saved as: rampa_profes_estacionamiento_2_51.csv.csv
#
# --- # 7 ---
# Original File: rampa_profes_estacionamiento_2_4.csv
# Points: 22081
# Saved as: rampa_profes_estacionamiento_2_4.csv.csv
#
# --- # 8 ---
# Original File: rampa_profes_estacionamiento_2_38.csv
# Points: 22067
# Saved as: rampa_profes_estacionamiento_2_38.csv.csv
#
# --- # 9 ---
# Original File: rampa_profes_estacionamiento_2_56.csv
# Points: 22059
# Saved as: rampa_profes_estacionamiento_2_56.csv.csv
#
# --- # 10 ---
# Original File: rampa_profes_estacionamiento_2_36.csv
# Points: 22075
# Saved as: rampa_profes_estacionamiento_2_36.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\asfalto
# ========================================

# %% [markdown]
# ## Concreto

# %%
class_name = 'concreto'

subdirectories = []
subdirectories = find_subdirectories_os(rf'c:\Users\USER\Desktop\Everything\{class_name}')

for subdir in subdirectories:
    df_shape = []
    good_frames = []
    time_stamp = []
    dataframes_dict = {}
    file_names = {} 

    carpeta = rf'c:\Users\USER\Desktop\Everything\{class_name}\{subdir}'
    output_dir = rf'C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\{class_name}'

    csv_files = glob.glob(os.path.join(carpeta, '**', '*.csv'), recursive=True)

    folder_name = os.path.basename(carpeta.rstrip('\\').rstrip('_'))
    print("="*40)
    print(f"\nFolder Name: {folder_name}")
    print(f"\nFound a total of {len(csv_files)} CSV files in the directory.")

    for i in range(len(csv_files)):
        df = pl.read_csv(csv_files[i], skip_rows=1)
        if is_good_frame(df):
            good_frames.append(i)
            std_val = df['# TIMESTAMP (ns)'].std()
            time_stamp.append([std_val, i])
            df_transformed = new_df(df)
            dataframes_dict[i] = df_transformed
            df_shape.append(df_transformed.shape)
            
            file_names[i] = os.path.basename(csv_files[i])

    print(f"Approved frames: {len(good_frames)}")

    os.makedirs(output_dir, exist_ok=True)

    if good_frames:
        if len(time_stamp) > 0:
            arr = np.array(time_stamp)
            
            if arr.ndim == 1:
                arr = arr.reshape(1, -1)
            
            sorted_arr = arr[arr[:, 0].argsort()[::-1]]
            num_frames = min(10, len(sorted_arr))
            top_10_indices = sorted_arr[:num_frames, 1].astype(int)
            
            top_10_dfs = {idx: dataframes_dict[idx] for idx in top_10_indices if idx in dataframes_dict}
            
            for rank, (idx, df) in enumerate(top_10_dfs.items(), 1):
                print(f'\n--- # {rank} ---')
                print(f'Original File: {file_names[idx]}')
                print(f'Points: {df.height}')
                
                ''' # Optional Visualization (Makes debugging easier)
                plt.figure(figsize=(6, 6))
                plt.scatter(df["X"], df["Y"], s=1, c=df["Z"], cmap="viridis")
                plt.xlabel("X (m)")
                plt.ylabel("Y (m)")
                plt.title(f"# {rank} - {file_names[idx]}\n(X vs Y) colored by Z")
                plt.colorbar(label="Height Z (m)")
                plt.xlim(-3, 3)
                plt.ylim(0, 3)
                plt.grid(True, alpha=0.3)
                plt.show()
                '''
                
                output_file = f'{output_dir}/{os.path.splitext(file_names[idx])[0]}.csv'
                df.write_csv(output_file)
                print(f'Saved as: {file_names[idx]}')
            
            print(f"Total: {len(top_10_dfs)} frames saved in {output_dir}")
            print("="*40)
        else:
            print("No timestamp data available to rank frames.")
# Out:
# ========================================
#
# Folder Name: concreto_ccu
#
# Found a total of 71 CSV files in the directory.
# Approved frames: 71
#
# --- # 1 ---
# Original File: cemento_ccu_5.csv
# Points: 21702
# Saved as: cemento_ccu_5.csv.csv
#
# --- # 2 ---
# Original File: cemento_ccu_26.csv
# Points: 21688
# Saved as: cemento_ccu_26.csv.csv
#
# --- # 3 ---
# Original File: cemento_ccu_25.csv
# Points: 21696
# Saved as: cemento_ccu_25.csv.csv
#
# --- # 4 ---
# Original File: cemento_ccu_30.csv
# Points: 21696
# Saved as: cemento_ccu_30.csv.csv
#
# --- # 5 ---
# Original File: cemento_ccu_7.csv
# Points: 21698
# Saved as: cemento_ccu_7.csv.csv
#
# --- # 6 ---
# Original File: cemento_ccu_61.csv
# Points: 21694
# Saved as: cemento_ccu_61.csv.csv
#
# --- # 7 ---
# Original File: cemento_ccu_68.csv
# Points: 21835
# Saved as: cemento_ccu_68.csv.csv
#
# --- # 8 ---
# Original File: cemento_ccu_64.csv
# Points: 21685
# Saved as: cemento_ccu_64.csv.csv
#
# --- # 9 ---
# Original File: cemento_ccu_49.csv
# Points: 21692
# Saved as: cemento_ccu_49.csv.csv
#
# --- # 10 ---
# Original File: cemento_ccu_66.csv
# Points: 21682
# Saved as: cemento_ccu_66.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\concreto
# ========================================
# ========================================
#
# Folder Name: concreto_ccu_2
#
# Found a total of 71 CSV files in the directory.
# Approved frames: 46
#
# --- # 1 ---
# Original File: cemento_ccu_2_38.csv
# Points: 19925
# Saved as: cemento_ccu_2_38.csv.csv
#
# --- # 2 ---
# Original File: cemento_ccu_2_51.csv
# Points: 19924
# Saved as: cemento_ccu_2_51.csv.csv
#
# --- # 3 ---
# Original File: cemento_ccu_2_9.csv
# Points: 19924
# Saved as: cemento_ccu_2_9.csv.csv
#
# --- # 4 ---
# Original File: cemento_ccu_2_16.csv
# Points: 19929
# Saved as: cemento_ccu_2_16.csv.csv
#
# --- # 5 ---
# Original File: cemento_ccu_2_28.csv
# Points: 19927
# Saved as: cemento_ccu_2_28.csv.csv
#
# --- # 6 ---
# Original File: cemento_ccu_2_10.csv
# Points: 19931
# Saved as: cemento_ccu_2_10.csv.csv
#
# --- # 7 ---
# Original File: cemento_ccu_2_46.csv
# Points: 19928
# Saved as: cemento_ccu_2_46.csv.csv
#
# --- # 8 ---
# Original File: cemento_ccu_2_45.csv
# Points: 19926
# Saved as: cemento_ccu_2_45.csv.csv
#
# --- # 9 ---
# Original File: cemento_ccu_2_68.csv
# Points: 19931
# Saved as: cemento_ccu_2_68.csv.csv
#
# --- # 10 ---
# Original File: cemento_ccu_2_20.csv
# Points: 19925
# Saved as: cemento_ccu_2_20.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\concreto
# ========================================
# ========================================
#
# Folder Name: concreto_restringido_vehiculos
#
# Found a total of 72 CSV files in the directory.
# Approved frames: 47
#
# --- # 1 ---
# Original File: adoquin_D_restringido_vehiculos_9.csv
# Points: 20957
# Saved as: adoquin_D_restringido_vehiculos_9.csv.csv
#
# --- # 2 ---
# Original File: adoquin_D_restringido_vehiculos_19.csv
# Points: 20962
# Saved as: adoquin_D_restringido_vehiculos_19.csv.csv
#
# --- # 3 ---
# Original File: adoquin_D_restringido_vehiculos_52.csv
# Points: 20958
# Saved as: adoquin_D_restringido_vehiculos_52.csv.csv
#
# --- # 4 ---
# Original File: adoquin_D_restringido_vehiculos_64.csv
# Points: 20955
# Saved as: adoquin_D_restringido_vehiculos_64.csv.csv
#
# --- # 5 ---
# Original File: adoquin_D_restringido_vehiculos_55.csv
# Points: 20964
# Saved as: adoquin_D_restringido_vehiculos_55.csv.csv
#
# --- # 6 ---
# Original File: adoquin_D_restringido_vehiculos_44.csv
# Points: 20961
# Saved as: adoquin_D_restringido_vehiculos_44.csv.csv
#
# --- # 7 ---
# Original File: adoquin_D_restringido_vehiculos_45.csv
# Points: 20961
# Saved as: adoquin_D_restringido_vehiculos_45.csv.csv
#
# --- # 8 ---
# Original File: adoquin_D_restringido_vehiculos_32.csv
# Points: 20959
# Saved as: adoquin_D_restringido_vehiculos_32.csv.csv
#
# --- # 9 ---
# Original File: adoquin_D_restringido_vehiculos_59.csv
# Points: 20952
# Saved as: adoquin_D_restringido_vehiculos_59.csv.csv
#
# --- # 10 ---
# Original File: adoquin_D_restringido_vehiculos_31.csv
# Points: 20955
# Saved as: adoquin_D_restringido_vehiculos_31.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\concreto
# ========================================
# ========================================
#
# Folder Name: concreto_rotonda_CCU
#
# Found a total of 74 CSV files in the directory.
# Approved frames: 56
#
# --- # 1 ---
# Original File: concreto_rotonda_CCU_13.csv
# Points: 21719
# Saved as: concreto_rotonda_CCU_13.csv.csv
#
# --- # 2 ---
# Original File: concreto_rotonda_CCU_43.csv
# Points: 21702
# Saved as: concreto_rotonda_CCU_43.csv.csv
#
# --- # 3 ---
# Original File: concreto_rotonda_CCU_30.csv
# Points: 21689
# Saved as: concreto_rotonda_CCU_30.csv.csv
#
# --- # 4 ---
# Original File: concreto_rotonda_CCU_55.csv
# Points: 21685
# Saved as: concreto_rotonda_CCU_55.csv.csv
#
# --- # 5 ---
# Original File: concreto_rotonda_CCU_50.csv
# Points: 21702
# Saved as: concreto_rotonda_CCU_50.csv.csv
#
# --- # 6 ---
# Original File: concreto_rotonda_CCU_19.csv
# Points: 21710
# Saved as: concreto_rotonda_CCU_19.csv.csv
#
# --- # 7 ---
# Original File: concreto_rotonda_CCU_42.csv
# Points: 21697
# Saved as: concreto_rotonda_CCU_42.csv.csv
#
# --- # 8 ---
# Original File: concreto_rotonda_CCU_15.csv
# Points: 21718
# Saved as: concreto_rotonda_CCU_15.csv.csv
#
# --- # 9 ---
# Original File: concreto_rotonda_CCU_25.csv
# Points: 21717
# Saved as: concreto_rotonda_CCU_25.csv.csv
#
# --- # 10 ---
# Original File: concreto_rotonda_CCU_26.csv
# Points: 21705
# Saved as: concreto_rotonda_CCU_26.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\concreto
# ========================================
# ========================================
#
# Folder Name: concreto_rotonda_CCU_2
#
# Found a total of 75 CSV files in the directory.
# Approved frames: 49
#
# --- # 1 ---
# Original File: concreto_rotonda_CCU_2_28.csv
# Points: 23172
# Saved as: concreto_rotonda_CCU_2_28.csv.csv
#
# --- # 2 ---
# Original File: concreto_rotonda_CCU_2_24.csv
# Points: 23176
# Saved as: concreto_rotonda_CCU_2_24.csv.csv
#
# --- # 3 ---
# Original File: concreto_rotonda_CCU_2_49.csv
# Points: 23166
# Saved as: concreto_rotonda_CCU_2_49.csv.csv
#
# --- # 4 ---
# Original File: concreto_rotonda_CCU_2_72.csv
# Points: 23179
# Saved as: concreto_rotonda_CCU_2_72.csv.csv
#
# --- # 5 ---
# Original File: concreto_rotonda_CCU_2_67.csv
# Points: 23178
# Saved as: concreto_rotonda_CCU_2_67.csv.csv
#
# --- # 6 ---
# Original File: concreto_rotonda_CCU_2_17.csv
# Points: 23175
# Saved as: concreto_rotonda_CCU_2_17.csv.csv
#
# --- # 7 ---
# Original File: concreto_rotonda_CCU_2_9.csv
# Points: 23178
# Saved as: concreto_rotonda_CCU_2_9.csv.csv
#
# --- # 8 ---
# Original File: concreto_rotonda_CCU_2_74.csv
# Points: 23172
# Saved as: concreto_rotonda_CCU_2_74.csv.csv
#
# --- # 9 ---
# Original File: concreto_rotonda_CCU_2_19.csv
# Points: 23170
# Saved as: concreto_rotonda_CCU_2_19.csv.csv
#
# --- # 10 ---
# Original File: concreto_rotonda_CCU_2_26.csv
# Points: 23174
# Saved as: concreto_rotonda_CCU_2_26.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\concreto
# ========================================
# ========================================
#
# Folder Name: concreto_rotonda_estacionamiento_profes
#
# Found a total of 76 CSV files in the directory.
# Approved frames: 39
#
# --- # 1 ---
# Original File: concreto_rotonda_estacionamiento_profes_14.csv
# Points: 22900
# Saved as: concreto_rotonda_estacionamiento_profes_14.csv.csv
#
# --- # 2 ---
# Original File: concreto_rotonda_estacionamiento_profes_21.csv
# Points: 22901
# Saved as: concreto_rotonda_estacionamiento_profes_21.csv.csv
#
# --- # 3 ---
# Original File: concreto_rotonda_estacionamiento_profes_53.csv
# Points: 22899
# Saved as: concreto_rotonda_estacionamiento_profes_53.csv.csv
#
# --- # 4 ---
# Original File: concreto_rotonda_estacionamiento_profes_72.csv
# Points: 22889
# Saved as: concreto_rotonda_estacionamiento_profes_72.csv.csv
#
# --- # 5 ---
# Original File: concreto_rotonda_estacionamiento_profes_30.csv
# Points: 22897
# Saved as: concreto_rotonda_estacionamiento_profes_30.csv.csv
#
# --- # 6 ---
# Original File: concreto_rotonda_estacionamiento_profes_8.csv
# Points: 22900
# Saved as: concreto_rotonda_estacionamiento_profes_8.csv.csv
#
# --- # 7 ---
# Original File: concreto_rotonda_estacionamiento_profes_27.csv
# Points: 22900
# Saved as: concreto_rotonda_estacionamiento_profes_27.csv.csv
#
# --- # 8 ---
# Original File: concreto_rotonda_estacionamiento_profes_51.csv
# Points: 22893
# Saved as: concreto_rotonda_estacionamiento_profes_51.csv.csv
#
# --- # 9 ---
# Original File: concreto_rotonda_estacionamiento_profes_43.csv
# Points: 22891
# Saved as: concreto_rotonda_estacionamiento_profes_43.csv.csv
#
# --- # 10 ---
# Original File: concreto_rotonda_estacionamiento_profes_33.csv
# Points: 22901
# Saved as: concreto_rotonda_estacionamiento_profes_33.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\concreto
# ========================================
# ========================================
#
# Folder Name: concreto_seven
#
# Found a total of 75 CSV files in the directory.
# Approved frames: 62
#
# --- # 1 ---
# Original File: adoquin_D_seven_50.csv
# Points: 21222
# Saved as: adoquin_D_seven_50.csv.csv
#
# --- # 2 ---
# Original File: adoquin_D_seven_5.csv
# Points: 21230
# Saved as: adoquin_D_seven_5.csv.csv
#
# --- # 3 ---
# Original File: adoquin_D_seven_66.csv
# Points: 21208
# Saved as: adoquin_D_seven_66.csv.csv
#
# --- # 4 ---
# Original File: adoquin_D_seven_57.csv
# Points: 21206
# Saved as: adoquin_D_seven_57.csv.csv
#
# --- # 5 ---
# Original File: adoquin_D_seven_46.csv
# Points: 21210
# Saved as: adoquin_D_seven_46.csv.csv
#
# --- # 6 ---
# Original File: adoquin_D_seven_48.csv
# Points: 21207
# Saved as: adoquin_D_seven_48.csv.csv
#
# --- # 7 ---
# Original File: adoquin_D_seven_63.csv
# Points: 21209
# Saved as: adoquin_D_seven_63.csv.csv
#
# --- # 8 ---
# Original File: adoquin_D_seven_31.csv
# Points: 21217
# Saved as: adoquin_D_seven_31.csv.csv
#
# --- # 9 ---
# Original File: adoquin_D_seven_47.csv
# Points: 21219
# Saved as: adoquin_D_seven_47.csv.csv
#
# --- # 10 ---
# Original File: adoquin_D_seven_9.csv
# Points: 21211
# Saved as: adoquin_D_seven_9.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\concreto
# ========================================
# ========================================
#
# Folder Name: concreto_solar
#
# Found a total of 86 CSV files in the directory.
# Approved frames: 79
#
# --- # 1 ---
# Original File: concreto_solar_61.csv
# Points: 21497
# Saved as: concreto_solar_61.csv.csv
#
# --- # 2 ---
# Original File: concreto_solar_44.csv
# Points: 21489
# Saved as: concreto_solar_44.csv.csv
#
# --- # 3 ---
# Original File: concreto_solar_66.csv
# Points: 21498
# Saved as: concreto_solar_66.csv.csv
#
# --- # 4 ---
# Original File: concreto_solar_34.csv
# Points: 21491
# Saved as: concreto_solar_34.csv.csv
#
# --- # 5 ---
# Original File: concreto_solar_52.csv
# Points: 21485
# Saved as: concreto_solar_52.csv.csv
#
# --- # 6 ---
# Original File: concreto_solar_77.csv
# Points: 21496
# Saved as: concreto_solar_77.csv.csv
#
# --- # 7 ---
# Original File: concreto_solar_53.csv
# Points: 21498
# Saved as: concreto_solar_53.csv.csv
#
# --- # 8 ---
# Original File: concreto_solar_28.csv
# Points: 21497
# Saved as: concreto_solar_28.csv.csv
#
# --- # 9 ---
# Original File: concreto_solar_7.csv
# Points: 21502
# Saved as: concreto_solar_7.csv.csv
#
# --- # 10 ---
# Original File: concreto_solar_0.csv
# Points: 21507
# Saved as: concreto_solar_0.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\concreto
# ========================================
# ========================================
#
# Folder Name: concreto_solar_2_estoa
#
# Found a total of 77 CSV files in the directory.
# Approved frames: 40
#
# --- # 1 ---
# Original File: concreto_solar_2_estoa_55.csv
# Points: 22360
# Saved as: concreto_solar_2_estoa_55.csv.csv
#
# --- # 2 ---
# Original File: concreto_solar_2_estoa_62.csv
# Points: 22364
# Saved as: concreto_solar_2_estoa_62.csv.csv
#
# --- # 3 ---
# Original File: concreto_solar_2_estoa_21.csv
# Points: 22374
# Saved as: concreto_solar_2_estoa_21.csv.csv
#
# --- # 4 ---
# Original File: concreto_solar_2_estoa_38.csv
# Points: 22366
# Saved as: concreto_solar_2_estoa_38.csv.csv
#
# --- # 5 ---
# Original File: concreto_solar_2_estoa_43.csv
# Points: 22366
# Saved as: concreto_solar_2_estoa_43.csv.csv
#
# --- # 6 ---
# Original File: concreto_solar_2_estoa_15.csv
# Points: 22374
# Saved as: concreto_solar_2_estoa_15.csv.csv
#
# --- # 7 ---
# Original File: concreto_solar_2_estoa_36.csv
# Points: 22369
# Saved as: concreto_solar_2_estoa_36.csv.csv
#
# --- # 8 ---
# Original File: concreto_solar_2_estoa_29.csv
# Points: 22366
# Saved as: concreto_solar_2_estoa_29.csv.csv
#
# --- # 9 ---
# Original File: concreto_solar_2_estoa_2.csv
# Points: 22369
# Saved as: concreto_solar_2_estoa_2.csv.csv
#
# --- # 10 ---
# Original File: concreto_solar_2_estoa_19.csv
# Points: 22383
# Saved as: concreto_solar_2_estoa_19.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\concreto
# ========================================
# ========================================
#
# Folder Name: concreto_solar_3_estoa
#
# Found a total of 75 CSV files in the directory.
# Approved frames: 51
#
# --- # 1 ---
# Original File: concreto_solar_3_estoa_18.csv
# Points: 21465
# Saved as: concreto_solar_3_estoa_18.csv.csv
#
# --- # 2 ---
# Original File: concreto_solar_3_estoa_62.csv
# Points: 21470
# Saved as: concreto_solar_3_estoa_62.csv.csv
#
# --- # 3 ---
# Original File: concreto_solar_3_estoa_71.csv
# Points: 21455
# Saved as: concreto_solar_3_estoa_71.csv.csv
#
# --- # 4 ---
# Original File: concreto_solar_3_estoa_72.csv
# Points: 21450
# Saved as: concreto_solar_3_estoa_72.csv.csv
#
# --- # 5 ---
# Original File: concreto_solar_3_estoa_35.csv
# Points: 21465
# Saved as: concreto_solar_3_estoa_35.csv.csv
#
# --- # 6 ---
# Original File: concreto_solar_3_estoa_0.csv
# Points: 21476
# Saved as: concreto_solar_3_estoa_0.csv.csv
#
# --- # 7 ---
# Original File: concreto_solar_3_estoa_26.csv
# Points: 21471
# Saved as: concreto_solar_3_estoa_26.csv.csv
#
# --- # 8 ---
# Original File: concreto_solar_3_estoa_23.csv
# Points: 21457
# Saved as: concreto_solar_3_estoa_23.csv.csv
#
# --- # 9 ---
# Original File: concreto_solar_3_estoa_58.csv
# Points: 21460
# Saved as: concreto_solar_3_estoa_58.csv.csv
#
# --- # 10 ---
# Original File: concreto_solar_3_estoa_8.csv
# Points: 21477
# Saved as: concreto_solar_3_estoa_8.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\concreto
# ========================================

# %% [markdown]
# ## Grava

# %%
class_name = 'grava'

subdirectories = []
subdirectories = find_subdirectories_os(rf'c:\Users\USER\Desktop\Everything\{class_name}')

for subdir in subdirectories:
    df_shape = []
    good_frames = []
    time_stamp = []
    dataframes_dict = {}
    file_names = {} 

    carpeta = rf'c:\Users\USER\Desktop\Everything\{class_name}\{subdir}'
    output_dir = rf'C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\{class_name}'

    csv_files = glob.glob(os.path.join(carpeta, '**', '*.csv'), recursive=True)

    folder_name = os.path.basename(carpeta.rstrip('\\').rstrip('_'))
    print("="*40)
    print(f"\nFolder Name: {folder_name}")
    print(f"\nFound a total of {len(csv_files)} CSV files in the directory.")

    for i in range(len(csv_files)):
        df = pl.read_csv(csv_files[i], skip_rows=1)
        if is_good_frame(df):
            good_frames.append(i)
            std_val = df['# TIMESTAMP (ns)'].std()
            time_stamp.append([std_val, i])
            df_transformed = new_df(df)
            dataframes_dict[i] = df_transformed
            df_shape.append(df_transformed.shape)
            
            file_names[i] = os.path.basename(csv_files[i])

    print(f"Approved frames: {len(good_frames)}")

    os.makedirs(output_dir, exist_ok=True)

    if good_frames:
        if len(time_stamp) > 0:
            arr = np.array(time_stamp)
            
            if arr.ndim == 1:
                arr = arr.reshape(1, -1)
            
            sorted_arr = arr[arr[:, 0].argsort()[::-1]]
            num_frames = min(10, len(sorted_arr))
            top_10_indices = sorted_arr[:num_frames, 1].astype(int)
            
            top_10_dfs = {idx: dataframes_dict[idx] for idx in top_10_indices if idx in dataframes_dict}
            
            for rank, (idx, df) in enumerate(top_10_dfs.items(), 1):
                print(f'\n--- # {rank} ---')
                print(f'Original File: {file_names[idx]}')
                print(f'Points: {df.height}')
                
                ''' # Optional Visualization (Makes debugging easier)
                plt.figure(figsize=(6, 6))
                plt.scatter(df["X"], df["Y"], s=1, c=df["Z"], cmap="viridis")
                plt.xlabel("X (m)")
                plt.ylabel("Y (m)")
                plt.title(f"# {rank} - {file_names[idx]}\n(X vs Y) colored by Z")
                plt.colorbar(label="Height Z (m)")
                plt.xlim(-3, 3)
                plt.ylim(0, 3)
                plt.grid(True, alpha=0.3)
                plt.show()
                '''
                
                output_file = f'{output_dir}/{os.path.splitext(file_names[idx])[0]}.csv'
                df.write_csv(output_file)
                print(f'Saved as: {file_names[idx]}.csv')
            
            print(f"Total: {len(top_10_dfs)} frames saved in {output_dir}")
            print("="*40)
        else:
            print("No timestamp data available to rank frames.")
# Out:
# ========================================
#
# Folder Name: grava_25deseptiembre
#
# Found a total of 82 CSV files in the directory.
# Approved frames: 70
#
# --- # 1 ---
# Original File: grava_25deseptiembre_33.csv
# Points: 24483
# Saved as: grava_25deseptiembre_33.csv.csv
#
# --- # 2 ---
# Original File: grava_25deseptiembre_44.csv
# Points: 24472
# Saved as: grava_25deseptiembre_44.csv.csv
#
# --- # 3 ---
# Original File: grava_25deseptiembre_35.csv
# Points: 24479
# Saved as: grava_25deseptiembre_35.csv.csv
#
# --- # 4 ---
# Original File: grava_25deseptiembre_53.csv
# Points: 24483
# Saved as: grava_25deseptiembre_53.csv.csv
#
# --- # 5 ---
# Original File: grava_25deseptiembre_12.csv
# Points: 24476
# Saved as: grava_25deseptiembre_12.csv.csv
#
# --- # 6 ---
# Original File: grava_25deseptiembre_7.csv
# Points: 24480
# Saved as: grava_25deseptiembre_7.csv.csv
#
# --- # 7 ---
# Original File: grava_25deseptiembre_74.csv
# Points: 24477
# Saved as: grava_25deseptiembre_74.csv.csv
#
# --- # 8 ---
# Original File: grava_25deseptiembre_40.csv
# Points: 24479
# Saved as: grava_25deseptiembre_40.csv.csv
#
# --- # 9 ---
# Original File: grava_25deseptiembre_6.csv
# Points: 24470
# Saved as: grava_25deseptiembre_6.csv.csv
#
# --- # 10 ---
# Original File: grava_25deseptiembre_67.csv
# Points: 24480
# Saved as: grava_25deseptiembre_67.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\grava
# ========================================
# ========================================
#
# Folder Name: grava_25deseptiembre_toma2
#
# Found a total of 74 CSV files in the directory.
# Approved frames: 65
#
# --- # 1 ---
# Original File: grava_25deseptiembre_toma2_43.csv
# Points: 19943
# Saved as: grava_25deseptiembre_toma2_43.csv.csv
#
# --- # 2 ---
# Original File: grava_25deseptiembre_toma2_29.csv
# Points: 19941
# Saved as: grava_25deseptiembre_toma2_29.csv.csv
#
# --- # 3 ---
# Original File: grava_25deseptiembre_toma2_62.csv
# Points: 19954
# Saved as: grava_25deseptiembre_toma2_62.csv.csv
#
# --- # 4 ---
# Original File: grava_25deseptiembre_toma2_50.csv
# Points: 19949
# Saved as: grava_25deseptiembre_toma2_50.csv.csv
#
# --- # 5 ---
# Original File: grava_25deseptiembre_toma2_55.csv
# Points: 19938
# Saved as: grava_25deseptiembre_toma2_55.csv.csv
#
# --- # 6 ---
# Original File: grava_25deseptiembre_toma2_22.csv
# Points: 19957
# Saved as: grava_25deseptiembre_toma2_22.csv.csv
#
# --- # 7 ---
# Original File: grava_25deseptiembre_toma2_60.csv
# Points: 19938
# Saved as: grava_25deseptiembre_toma2_60.csv.csv
#
# --- # 8 ---
# Original File: grava_25deseptiembre_toma2_46.csv
# Points: 19943
# Saved as: grava_25deseptiembre_toma2_46.csv.csv
#
# --- # 9 ---
# Original File: grava_25deseptiembre_toma2_33.csv
# Points: 19948
# Saved as: grava_25deseptiembre_toma2_33.csv.csv
#
# --- # 10 ---
# Original File: grava_25deseptiembre_toma2_66.csv
# Points: 19931
# Saved as: grava_25deseptiembre_toma2_66.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\grava
# ========================================
# ========================================
#
# Folder Name: grava_estacionamientooooo
#
# Found a total of 74 CSV files in the directory.
# Approved frames: 57
#
# --- # 1 ---
# Original File: grava_estacionamientooooo_40.csv
# Points: 24590
# Saved as: grava_estacionamientooooo_40.csv.csv
#
# --- # 2 ---
# Original File: grava_estacionamientooooo_33.csv
# Points: 24602
# Saved as: grava_estacionamientooooo_33.csv.csv
#
# --- # 3 ---
# Original File: grava_estacionamientooooo_62.csv
# Points: 24599
# Saved as: grava_estacionamientooooo_62.csv.csv
#
# --- # 4 ---
# Original File: grava_estacionamientooooo_26.csv
# Points: 24600
# Saved as: grava_estacionamientooooo_26.csv.csv
#
# --- # 5 ---
# Original File: grava_estacionamientooooo_49.csv
# Points: 24595
# Saved as: grava_estacionamientooooo_49.csv.csv
#
# --- # 6 ---
# Original File: grava_estacionamientooooo_19.csv
# Points: 24593
# Saved as: grava_estacionamientooooo_19.csv.csv
#
# --- # 7 ---
# Original File: grava_estacionamientooooo_17.csv
# Points: 24597
# Saved as: grava_estacionamientooooo_17.csv.csv
#
# --- # 8 ---
# Original File: grava_estacionamientooooo_27.csv
# Points: 24591
# Saved as: grava_estacionamientooooo_27.csv.csv
#
# --- # 9 ---
# Original File: grava_estacionamientooooo_44.csv
# Points: 24594
# Saved as: grava_estacionamientooooo_44.csv.csv
#
# --- # 10 ---
# Original File: grava_estacionamientooooo_10.csv
# Points: 24606
# Saved as: grava_estacionamientooooo_10.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\grava
# ========================================
# ========================================
#
# Folder Name: grava_estacionamientooooo_2
#
# Found a total of 77 CSV files in the directory.
# Approved frames: 64
#
# --- # 1 ---
# Original File: grava_estacionamientooooo_2_20.csv
# Points: 24584
# Saved as: grava_estacionamientooooo_2_20.csv.csv
#
# --- # 2 ---
# Original File: grava_estacionamientooooo_2_72.csv
# Points: 24574
# Saved as: grava_estacionamientooooo_2_72.csv.csv
#
# --- # 3 ---
# Original File: grava_estacionamientooooo_2_56.csv
# Points: 24577
# Saved as: grava_estacionamientooooo_2_56.csv.csv
#
# --- # 4 ---
# Original File: grava_estacionamientooooo_2_37.csv
# Points: 24578
# Saved as: grava_estacionamientooooo_2_37.csv.csv
#
# --- # 5 ---
# Original File: grava_estacionamientooooo_2_24.csv
# Points: 24591
# Saved as: grava_estacionamientooooo_2_24.csv.csv
#
# --- # 6 ---
# Original File: grava_estacionamientooooo_2_34.csv
# Points: 24584
# Saved as: grava_estacionamientooooo_2_34.csv.csv
#
# --- # 7 ---
# Original File: grava_estacionamientooooo_2_15.csv
# Points: 24577
# Saved as: grava_estacionamientooooo_2_15.csv.csv
#
# --- # 8 ---
# Original File: grava_estacionamientooooo_2_38.csv
# Points: 24579
# Saved as: grava_estacionamientooooo_2_38.csv.csv
#
# --- # 9 ---
# Original File: grava_estacionamientooooo_2_19.csv
# Points: 24578
# Saved as: grava_estacionamientooooo_2_19.csv.csv
#
# --- # 10 ---
# Original File: grava_estacionamientooooo_2_2.csv
# Points: 24582
# Saved as: grava_estacionamientooooo_2_2.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\grava
# ========================================
# ========================================
#
# Folder Name: grava_estacionamientooooo_3
#
# Found a total of 73 CSV files in the directory.
# Approved frames: 55
#
# --- # 1 ---
# Original File: grava_estacionamientooooo_3_9.csv
# Points: 24696
# Saved as: grava_estacionamientooooo_3_9.csv.csv
#
# --- # 2 ---
# Original File: grava_estacionamientooooo_3_40.csv
# Points: 24702
# Saved as: grava_estacionamientooooo_3_40.csv.csv
#
# --- # 3 ---
# Original File: grava_estacionamientooooo_3_47.csv
# Points: 24697
# Saved as: grava_estacionamientooooo_3_47.csv.csv
#
# --- # 4 ---
# Original File: grava_estacionamientooooo_3_38.csv
# Points: 24697
# Saved as: grava_estacionamientooooo_3_38.csv.csv
#
# --- # 5 ---
# Original File: grava_estacionamientooooo_3_66.csv
# Points: 24695
# Saved as: grava_estacionamientooooo_3_66.csv.csv
#
# --- # 6 ---
# Original File: grava_estacionamientooooo_3_69.csv
# Points: 24695
# Saved as: grava_estacionamientooooo_3_69.csv.csv
#
# --- # 7 ---
# Original File: grava_estacionamientooooo_3_61.csv
# Points: 24694
# Saved as: grava_estacionamientooooo_3_61.csv.csv
#
# --- # 8 ---
# Original File: grava_estacionamientooooo_3_44.csv
# Points: 24695
# Saved as: grava_estacionamientooooo_3_44.csv.csv
#
# --- # 9 ---
# Original File: grava_estacionamientooooo_3_42.csv
# Points: 24689
# Saved as: grava_estacionamientooooo_3_42.csv.csv
#
# --- # 10 ---
# Original File: grava_estacionamientooooo_3_54.csv
# Points: 24688
# Saved as: grava_estacionamientooooo_3_54.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\grava
# ========================================
# ========================================
#
# Folder Name: grava_estacionamiento_ccu
#
# Found a total of 79 CSV files in the directory.
# Approved frames: 71
#
# --- # 1 ---
# Original File: grava_estacionamiento_ccu_61.csv
# Points: 23502
# Saved as: grava_estacionamiento_ccu_61.csv.csv
#
# --- # 2 ---
# Original File: grava_estacionamiento_ccu_26.csv
# Points: 23503
# Saved as: grava_estacionamiento_ccu_26.csv.csv
#
# --- # 3 ---
# Original File: grava_estacionamiento_ccu_40.csv
# Points: 23511
# Saved as: grava_estacionamiento_ccu_40.csv.csv
#
# --- # 4 ---
# Original File: grava_estacionamiento_ccu_45.csv
# Points: 23511
# Saved as: grava_estacionamiento_ccu_45.csv.csv
#
# --- # 5 ---
# Original File: grava_estacionamiento_ccu_34.csv
# Points: 23517
# Saved as: grava_estacionamiento_ccu_34.csv.csv
#
# --- # 6 ---
# Original File: grava_estacionamiento_ccu_22.csv
# Points: 23509
# Saved as: grava_estacionamiento_ccu_22.csv.csv
#
# --- # 7 ---
# Original File: grava_estacionamiento_ccu_9.csv
# Points: 23505
# Saved as: grava_estacionamiento_ccu_9.csv.csv
#
# --- # 8 ---
# Original File: grava_estacionamiento_ccu_30.csv
# Points: 23487
# Saved as: grava_estacionamiento_ccu_30.csv.csv
#
# --- # 9 ---
# Original File: grava_estacionamiento_ccu_19.csv
# Points: 23507
# Saved as: grava_estacionamiento_ccu_19.csv.csv
#
# --- # 10 ---
# Original File: grava_estacionamiento_ccu_16.csv
# Points: 23505
# Saved as: grava_estacionamiento_ccu_16.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\grava
# ========================================
# ========================================
#
# Folder Name: grava_estacionamiento_ccu_2
#
# Found a total of 76 CSV files in the directory.
# Approved frames: 48
#
# --- # 1 ---
# Original File: grava_estacionamiento_ccu_2_7.csv
# Points: 22944
# Saved as: grava_estacionamiento_ccu_2_7.csv.csv
#
# --- # 2 ---
# Original File: grava_estacionamiento_ccu_2_22.csv
# Points: 22939
# Saved as: grava_estacionamiento_ccu_2_22.csv.csv
#
# --- # 3 ---
# Original File: grava_estacionamiento_ccu_2_19.csv
# Points: 22933
# Saved as: grava_estacionamiento_ccu_2_19.csv.csv
#
# --- # 4 ---
# Original File: grava_estacionamiento_ccu_2_48.csv
# Points: 22938
# Saved as: grava_estacionamiento_ccu_2_48.csv.csv
#
# --- # 5 ---
# Original File: grava_estacionamiento_ccu_2_0.csv
# Points: 22938
# Saved as: grava_estacionamiento_ccu_2_0.csv.csv
#
# --- # 6 ---
# Original File: grava_estacionamiento_ccu_2_75.csv
# Points: 22944
# Saved as: grava_estacionamiento_ccu_2_75.csv.csv
#
# --- # 7 ---
# Original File: grava_estacionamiento_ccu_2_58.csv
# Points: 22933
# Saved as: grava_estacionamiento_ccu_2_58.csv.csv
#
# --- # 8 ---
# Original File: grava_estacionamiento_ccu_2_28.csv
# Points: 22942
# Saved as: grava_estacionamiento_ccu_2_28.csv.csv
#
# --- # 9 ---
# Original File: grava_estacionamiento_ccu_2_64.csv
# Points: 22943
# Saved as: grava_estacionamiento_ccu_2_64.csv.csv
#
# --- # 10 ---
# Original File: grava_estacionamiento_ccu_2_2.csv
# Points: 22935
# Saved as: grava_estacionamiento_ccu_2_2.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\grava
# ========================================

# %% [markdown]
# ## Pasto

# %%
class_name = 'pasto'

subdirectories = []
subdirectories = find_subdirectories_os(rf'c:\Users\USER\Desktop\Everything\{class_name}')

for subdir in subdirectories:
    df_shape = []
    good_frames = []
    time_stamp = []
    dataframes_dict = {}
    file_names = {} 

    carpeta = rf'c:\Users\USER\Desktop\Everything\{class_name}\{subdir}'
    output_dir = rf'C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\{class_name}'

    csv_files = glob.glob(os.path.join(carpeta, '**', '*.csv'), recursive=True)

    folder_name = os.path.basename(carpeta.rstrip('\\').rstrip('_'))
    print("="*40)
    print(f"\nFolder Name: {folder_name}")
    print(f"\nFound a total of {len(csv_files)} CSV files in the directory.")

    for i in range(len(csv_files)):
        df = pl.read_csv(csv_files[i], skip_rows=1)
        if is_good_frame(df):
            good_frames.append(i)
            std_val = df['# TIMESTAMP (ns)'].std()
            time_stamp.append([std_val, i])
            df_transformed = new_df(df)
            dataframes_dict[i] = df_transformed
            df_shape.append(df_transformed.shape)
            
            file_names[i] = os.path.basename(csv_files[i])

    print(f"Approved frames: {len(good_frames)}")

    os.makedirs(output_dir, exist_ok=True)

    if good_frames:
        if len(time_stamp) > 0:
            arr = np.array(time_stamp)
            
            if arr.ndim == 1:
                arr = arr.reshape(1, -1)
            
            sorted_arr = arr[arr[:, 0].argsort()[::-1]]
            num_frames = min(10, len(sorted_arr))
            top_10_indices = sorted_arr[:num_frames, 1].astype(int)
            
            top_10_dfs = {idx: dataframes_dict[idx] for idx in top_10_indices if idx in dataframes_dict}
            
            for rank, (idx, df) in enumerate(top_10_dfs.items(), 1):
                print(f'\n--- # {rank} ---')
                print(f'Original File: {file_names[idx]}')
                print(f'Points: {df.height}')
                
                ''' # Optional Visualization (Makes debugging easier)
                plt.figure(figsize=(6, 6))
                plt.scatter(df["X"], df["Y"], s=1, c=df["Z"], cmap="viridis")
                plt.xlabel("X (m)")
                plt.ylabel("Y (m)")
                plt.title(f"# {rank} - {file_names[idx]}\n(X vs Y) colored by Z")
                plt.colorbar(label="Height Z (m)")
                plt.xlim(-3, 3)
                plt.ylim(0, 3)
                plt.grid(True, alpha=0.3)
                plt.show()
                '''
                
                output_file = f'{output_dir}/{os.path.splitext(file_names[idx])[0]}.csv'
                df.write_csv(output_file)
                print(f'Saved as: {file_names[idx]}.csv')
            
            print(f"Total: {len(top_10_dfs)} frames saved in {output_dir}")
            print("="*40)
        else:
            print("No timestamp data available to rank frames.")
# Out:
# ========================================
#
# Folder Name: cancha_de_futbol_1
#
# Found a total of 74 CSV files in the directory.
# Approved frames: 72
#
# --- # 1 ---
# Original File: cancha_de_futbol_1_17.csv
# Points: 21881
# Saved as: cancha_de_futbol_1_17.csv.csv
#
# --- # 2 ---
# Original File: cancha_de_futbol_1_5.csv
# Points: 21877
# Saved as: cancha_de_futbol_1_5.csv.csv
#
# --- # 3 ---
# Original File: cancha_de_futbol_1_68.csv
# Points: 21871
# Saved as: cancha_de_futbol_1_68.csv.csv
#
# --- # 4 ---
# Original File: cancha_de_futbol_1_55.csv
# Points: 21867
# Saved as: cancha_de_futbol_1_55.csv.csv
#
# --- # 5 ---
# Original File: cancha_de_futbol_1_10.csv
# Points: 21892
# Saved as: cancha_de_futbol_1_10.csv.csv
#
# --- # 6 ---
# Original File: cancha_de_futbol_1_29.csv
# Points: 21886
# Saved as: cancha_de_futbol_1_29.csv.csv
#
# --- # 7 ---
# Original File: cancha_de_futbol_1_43.csv
# Points: 21882
# Saved as: cancha_de_futbol_1_43.csv.csv
#
# --- # 8 ---
# Original File: cancha_de_futbol_1_39.csv
# Points: 21888
# Saved as: cancha_de_futbol_1_39.csv.csv
#
# --- # 9 ---
# Original File: cancha_de_futbol_1_63.csv
# Points: 21874
# Saved as: cancha_de_futbol_1_63.csv.csv
#
# --- # 10 ---
# Original File: cancha_de_futbol_1_54.csv
# Points: 21873
# Saved as: cancha_de_futbol_1_54.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\pasto
# ========================================
# ========================================
#
# Folder Name: cancha_de_futbol_2
#
# Found a total of 75 CSV files in the directory.
# Approved frames: 70
#
# --- # 1 ---
# Original File: cancha_de_futbol_2_63.csv
# Points: 22772
# Saved as: cancha_de_futbol_2_63.csv.csv
#
# --- # 2 ---
# Original File: cancha_de_futbol_2_69.csv
# Points: 22773
# Saved as: cancha_de_futbol_2_69.csv.csv
#
# --- # 3 ---
# Original File: cancha_de_futbol_2_2.csv
# Points: 22773
# Saved as: cancha_de_futbol_2_2.csv.csv
#
# --- # 4 ---
# Original File: cancha_de_futbol_2_56.csv
# Points: 22772
# Saved as: cancha_de_futbol_2_56.csv.csv
#
# --- # 5 ---
# Original File: cancha_de_futbol_2_65.csv
# Points: 22765
# Saved as: cancha_de_futbol_2_65.csv.csv
#
# --- # 6 ---
# Original File: cancha_de_futbol_2_49.csv
# Points: 22770
# Saved as: cancha_de_futbol_2_49.csv.csv
#
# --- # 7 ---
# Original File: cancha_de_futbol_2_9.csv
# Points: 22773
# Saved as: cancha_de_futbol_2_9.csv.csv
#
# --- # 8 ---
# Original File: cancha_de_futbol_2_18.csv
# Points: 22785
# Saved as: cancha_de_futbol_2_18.csv.csv
#
# --- # 9 ---
# Original File: cancha_de_futbol_2_34.csv
# Points: 22783
# Saved as: cancha_de_futbol_2_34.csv.csv
#
# --- # 10 ---
# Original File: cancha_de_futbol_2_45.csv
# Points: 22777
# Saved as: cancha_de_futbol_2_45.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\pasto
# ========================================
# ========================================
#
# Folder Name: cancha_de_futbol_3
#
# Found a total of 77 CSV files in the directory.
# Approved frames: 52
#
# --- # 1 ---
# Original File: cancha_de_futbol_3_15.csv
# Points: 22828
# Saved as: cancha_de_futbol_3_15.csv.csv
#
# --- # 2 ---
# Original File: cancha_de_futbol_3_18.csv
# Points: 22839
# Saved as: cancha_de_futbol_3_18.csv.csv
#
# --- # 3 ---
# Original File: cancha_de_futbol_3_55.csv
# Points: 22824
# Saved as: cancha_de_futbol_3_55.csv.csv
#
# --- # 4 ---
# Original File: cancha_de_futbol_3_0.csv
# Points: 22842
# Saved as: cancha_de_futbol_3_0.csv.csv
#
# --- # 5 ---
# Original File: cancha_de_futbol_3_49.csv
# Points: 22823
# Saved as: cancha_de_futbol_3_49.csv.csv
#
# --- # 6 ---
# Original File: cancha_de_futbol_3_10.csv
# Points: 22832
# Saved as: cancha_de_futbol_3_10.csv.csv
#
# --- # 7 ---
# Original File: cancha_de_futbol_3_21.csv
# Points: 22826
# Saved as: cancha_de_futbol_3_21.csv.csv
#
# --- # 8 ---
# Original File: cancha_de_futbol_3_25.csv
# Points: 22827
# Saved as: cancha_de_futbol_3_25.csv.csv
#
# --- # 9 ---
# Original File: cancha_de_futbol_3_47.csv
# Points: 22825
# Saved as: cancha_de_futbol_3_47.csv.csv
#
# --- # 10 ---
# Original File: cancha_de_futbol_3_61.csv
# Points: 22820
# Saved as: cancha_de_futbol_3_61.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\pasto
# ========================================
# ========================================
#
# Folder Name: pasto_aguas_negras_sombra
#
# Found a total of 72 CSV files in the directory.
# Approved frames: 49
#
# --- # 1 ---
# Original File: aguas_negras_16.csv
# Points: 25056
# Saved as: aguas_negras_16.csv.csv
#
# --- # 2 ---
# Original File: aguas_negras_9.csv
# Points: 25049
# Saved as: aguas_negras_9.csv.csv
#
# --- # 3 ---
# Original File: aguas_negras_28.csv
# Points: 25054
# Saved as: aguas_negras_28.csv.csv
#
# --- # 4 ---
# Original File: aguas_negras_37.csv
# Points: 25052
# Saved as: aguas_negras_37.csv.csv
#
# --- # 5 ---
# Original File: aguas_negras_13.csv
# Points: 25058
# Saved as: aguas_negras_13.csv.csv
#
# --- # 6 ---
# Original File: aguas_negras_62.csv
# Points: 25043
# Saved as: aguas_negras_62.csv.csv
#
# --- # 7 ---
# Original File: aguas_negras_54.csv
# Points: 25047
# Saved as: aguas_negras_54.csv.csv
#
# --- # 8 ---
# Original File: aguas_negras_25.csv
# Points: 25054
# Saved as: aguas_negras_25.csv.csv
#
# --- # 9 ---
# Original File: aguas_negras_71.csv
# Points: 25049
# Saved as: aguas_negras_71.csv.csv
#
# --- # 10 ---
# Original File: aguas_negras_47.csv
# Points: 25046
# Saved as: aguas_negras_47.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\pasto
# ========================================
# ========================================
#
# Folder Name: pasto_crgs_1
#
# Found a total of 73 CSV files in the directory.
# Approved frames: 56
#
# --- # 1 ---
# Original File: crgs_pasto_1_20.csv
# Points: 23723
# Saved as: crgs_pasto_1_20.csv.csv
#
# --- # 2 ---
# Original File: crgs_pasto_1_22.csv
# Points: 23731
# Saved as: crgs_pasto_1_22.csv.csv
#
# --- # 3 ---
# Original File: crgs_pasto_1_57.csv
# Points: 23721
# Saved as: crgs_pasto_1_57.csv.csv
#
# --- # 4 ---
# Original File: crgs_pasto_1_12.csv
# Points: 23734
# Saved as: crgs_pasto_1_12.csv.csv
#
# --- # 5 ---
# Original File: crgs_pasto_1_42.csv
# Points: 23730
# Saved as: crgs_pasto_1_42.csv.csv
#
# --- # 6 ---
# Original File: crgs_pasto_1_52.csv
# Points: 23721
# Saved as: crgs_pasto_1_52.csv.csv
#
# --- # 7 ---
# Original File: crgs_pasto_1_67.csv
# Points: 23717
# Saved as: crgs_pasto_1_67.csv.csv
#
# --- # 8 ---
# Original File: crgs_pasto_1_55.csv
# Points: 23716
# Saved as: crgs_pasto_1_55.csv.csv
#
# --- # 9 ---
# Original File: crgs_pasto_1_59.csv
# Points: 23721
# Saved as: crgs_pasto_1_59.csv.csv
#
# --- # 10 ---
# Original File: crgs_pasto_1_72.csv
# Points: 23719
# Saved as: crgs_pasto_1_72.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\pasto
# ========================================
# ========================================
#
# Folder Name: pasto_crgs_2
#
# Found a total of 73 CSV files in the directory.
# Approved frames: 28
#
# --- # 1 ---
# Original File: crgs_pasto_2_50.csv
# Points: 22554
# Saved as: crgs_pasto_2_50.csv.csv
#
# --- # 2 ---
# Original File: crgs_pasto_2_38.csv
# Points: 22542
# Saved as: crgs_pasto_2_38.csv.csv
#
# --- # 3 ---
# Original File: crgs_pasto_2_8.csv
# Points: 22552
# Saved as: crgs_pasto_2_8.csv.csv
#
# --- # 4 ---
# Original File: crgs_pasto_2_29.csv
# Points: 22558
# Saved as: crgs_pasto_2_29.csv.csv
#
# --- # 5 ---
# Original File: crgs_pasto_2_17.csv
# Points: 22559
# Saved as: crgs_pasto_2_17.csv.csv
#
# --- # 6 ---
# Original File: crgs_pasto_2_18.csv
# Points: 22564
# Saved as: crgs_pasto_2_18.csv.csv
#
# --- # 7 ---
# Original File: crgs_pasto_2_52.csv
# Points: 22547
# Saved as: crgs_pasto_2_52.csv.csv
#
# --- # 8 ---
# Original File: crgs_pasto_2_21.csv
# Points: 22550
# Saved as: crgs_pasto_2_21.csv.csv
#
# --- # 9 ---
# Original File: crgs_pasto_2_65.csv
# Points: 22548
# Saved as: crgs_pasto_2_65.csv.csv
#
# --- # 10 ---
# Original File: crgs_pasto_2_25.csv
# Points: 22554
# Saved as: crgs_pasto_2_25.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\pasto
# ========================================
# ========================================
#
# Folder Name: pasto_entre_ccu_y_biblioteca
#
# Found a total of 73 CSV files in the directory.
# Approved frames: 38
#
# --- # 1 ---
# Original File: entre_ccu_y_rectoria_48.csv
# Points: 23840
# Saved as: entre_ccu_y_rectoria_48.csv.csv
#
# --- # 2 ---
# Original File: entre_ccu_y_rectoria_44.csv
# Points: 23839
# Saved as: entre_ccu_y_rectoria_44.csv.csv
#
# --- # 3 ---
# Original File: entre_ccu_y_rectoria_19.csv
# Points: 23843
# Saved as: entre_ccu_y_rectoria_19.csv.csv
#
# --- # 4 ---
# Original File: entre_ccu_y_rectoria_52.csv
# Points: 23841
# Saved as: entre_ccu_y_rectoria_52.csv.csv
#
# --- # 5 ---
# Original File: entre_ccu_y_rectoria_25.csv
# Points: 23834
# Saved as: entre_ccu_y_rectoria_25.csv.csv
#
# --- # 6 ---
# Original File: entre_ccu_y_rectoria_39.csv
# Points: 23834
# Saved as: entre_ccu_y_rectoria_39.csv.csv
#
# --- # 7 ---
# Original File: entre_ccu_y_rectoria_20.csv
# Points: 23842
# Saved as: entre_ccu_y_rectoria_20.csv.csv
#
# --- # 8 ---
# Original File: entre_ccu_y_rectoria_55.csv
# Points: 23833
# Saved as: entre_ccu_y_rectoria_55.csv.csv
#
# --- # 9 ---
# Original File: entre_ccu_y_rectoria_22.csv
# Points: 23845
# Saved as: entre_ccu_y_rectoria_22.csv.csv
#
# --- # 10 ---
# Original File: entre_ccu_y_rectoria_61.csv
# Points: 23847
# Saved as: entre_ccu_y_rectoria_61.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\pasto
# ========================================
# ========================================
#
# Folder Name: pasto_jardin_abajo_papas_1_sombra
#
# Found a total of 73 CSV files in the directory.
# Approved frames: 55
#
# --- # 1 ---
# Original File: jardin_abajo_papas_1_20.csv
# Points: 24876
# Saved as: jardin_abajo_papas_1_20.csv.csv
#
# --- # 2 ---
# Original File: jardin_abajo_papas_1_30.csv
# Points: 24883
# Saved as: jardin_abajo_papas_1_30.csv.csv
#
# --- # 3 ---
# Original File: jardin_abajo_papas_1_22.csv
# Points: 24889
# Saved as: jardin_abajo_papas_1_22.csv.csv
#
# --- # 4 ---
# Original File: jardin_abajo_papas_1_66.csv
# Points: 24884
# Saved as: jardin_abajo_papas_1_66.csv.csv
#
# --- # 5 ---
# Original File: jardin_abajo_papas_1_42.csv
# Points: 24886
# Saved as: jardin_abajo_papas_1_42.csv.csv
#
# --- # 6 ---
# Original File: jardin_abajo_papas_1_57.csv
# Points: 24884
# Saved as: jardin_abajo_papas_1_57.csv.csv
#
# --- # 7 ---
# Original File: jardin_abajo_papas_1_19.csv
# Points: 24881
# Saved as: jardin_abajo_papas_1_19.csv.csv
#
# --- # 8 ---
# Original File: jardin_abajo_papas_1_62.csv
# Points: 24886
# Saved as: jardin_abajo_papas_1_62.csv.csv
#
# --- # 9 ---
# Original File: jardin_abajo_papas_1_12.csv
# Points: 24882
# Saved as: jardin_abajo_papas_1_12.csv.csv
#
# --- # 10 ---
# Original File: jardin_abajo_papas_1_65.csv
# Points: 24879
# Saved as: jardin_abajo_papas_1_65.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\pasto
# ========================================
# ========================================
#
# Folder Name: pasto_rectoria_1
#
# Found a total of 74 CSV files in the directory.
# Approved frames: 31
#
# --- # 1 ---
# Original File: pasto_rectoria_1_60.csv
# Points: 23191
# Saved as: pasto_rectoria_1_60.csv.csv
#
# --- # 2 ---
# Original File: pasto_rectoria_1_37.csv
# Points: 23194
# Saved as: pasto_rectoria_1_37.csv.csv
#
# --- # 3 ---
# Original File: pasto_rectoria_1_33.csv
# Points: 23184
# Saved as: pasto_rectoria_1_33.csv.csv
#
# --- # 4 ---
# Original File: pasto_rectoria_1_56.csv
# Points: 23193
# Saved as: pasto_rectoria_1_56.csv.csv
#
# --- # 5 ---
# Original File: pasto_rectoria_1_0.csv
# Points: 23210
# Saved as: pasto_rectoria_1_0.csv.csv
#
# --- # 6 ---
# Original File: pasto_rectoria_1_71.csv
# Points: 23188
# Saved as: pasto_rectoria_1_71.csv.csv
#
# --- # 7 ---
# Original File: pasto_rectoria_1_2.csv
# Points: 23190
# Saved as: pasto_rectoria_1_2.csv.csv
#
# --- # 8 ---
# Original File: pasto_rectoria_1_43.csv
# Points: 23193
# Saved as: pasto_rectoria_1_43.csv.csv
#
# --- # 9 ---
# Original File: pasto_rectoria_1_45.csv
# Points: 23197
# Saved as: pasto_rectoria_1_45.csv.csv
#
# --- # 10 ---
# Original File: pasto_rectoria_1_36.csv
# Points: 23187
# Saved as: pasto_rectoria_1_36.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\pasto
# ========================================
# ========================================
#
# Folder Name: pasto_rectoria_2
#
# Found a total of 72 CSV files in the directory.
# Approved frames: 48
#
# --- # 1 ---
# Original File: pasto_rectoria_2_38.csv
# Points: 22024
# Saved as: pasto_rectoria_2_38.csv.csv
#
# --- # 2 ---
# Original File: pasto_rectoria_2_45.csv
# Points: 22026
# Saved as: pasto_rectoria_2_45.csv.csv
#
# --- # 3 ---
# Original File: pasto_rectoria_2_60.csv
# Points: 22021
# Saved as: pasto_rectoria_2_60.csv.csv
#
# --- # 4 ---
# Original File: pasto_rectoria_2_40.csv
# Points: 22010
# Saved as: pasto_rectoria_2_40.csv.csv
#
# --- # 5 ---
# Original File: pasto_rectoria_2_19.csv
# Points: 22015
# Saved as: pasto_rectoria_2_19.csv.csv
#
# --- # 6 ---
# Original File: pasto_rectoria_2_23.csv
# Points: 22009
# Saved as: pasto_rectoria_2_23.csv.csv
#
# --- # 7 ---
# Original File: pasto_rectoria_2_51.csv
# Points: 22023
# Saved as: pasto_rectoria_2_51.csv.csv
#
# --- # 8 ---
# Original File: pasto_rectoria_2_39.csv
# Points: 22012
# Saved as: pasto_rectoria_2_39.csv.csv
#
# --- # 9 ---
# Original File: pasto_rectoria_2_28.csv
# Points: 22020
# Saved as: pasto_rectoria_2_28.csv.csv
#
# --- # 10 ---
# Original File: pasto_rectoria_2_66.csv
# Points: 22021
# Saved as: pasto_rectoria_2_66.csv.csv
# Total: 10 frames saved in C:\\Users\\USER\\PEF\\Terrain-Traversability-Analysis\\Preprocessing_10\\pasto
# ========================================
