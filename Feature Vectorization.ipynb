# %% [markdown]
# # Feature Vectorization
# Authors: Joel Enrique Díaz Villanueva, Fernando Lopez Barbosa
#
# Organization: Universidad de Monterrey
#
# Created: 28 November 2025
#
# ---

# %%
import os, sys
os.chdir("C:/Users/USER/PEF/Terrain-Traversability-Analysis")
sys.path.append(os.getcwd())
import glob
from FeatureHelpers2 import process_dataframe_optimized, find_subdirectories_os
import polars as pl
import joblib
import numpy as np
from tqdm.notebook import tqdm

# %%
class_name = ['adoquin', 'asfalto', 'concreto', 'grava', 'pasto']

for class_label in class_name:
    base_path = rf'C:\Users\USER\PEF\Terrain-Traversability-Analysis\Preprocessing_10\{class_label}' # Global folder path
    print(f"\nFolder Name: {base_path}")
    output_path = rf'C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\{class_label}'
    os.makedirs(output_path, exist_ok=True)
    
    csv_files = glob.glob(os.path.join(base_path, '**', '*.csv'), recursive=True)
    print(f"\nFound a total of {len(csv_files)} CSV files in the directory.")

    for i in tqdm(csv_files):
        filename = os.path.splitext(os.path.basename(i))[0]
        output_file = os.path.join(output_path, f'{filename}_features.csv')
        process_dataframe_optimized(i, output_file, class_label, n_neighbors=10)

    print(f"Completed {class_label}: {len(csv_files)} files processed\n")
    print("\n" + "="*70)
    
print("All classes processed successfully.")
# Out:
# Folder Name: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Preprocessing_10\adoquin
#
# Found a total of 100 CSV files in the directory.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Processing 23,337 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23337, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_atras_de_rectoria_15_features.csv
# Processing 23,330 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23330, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_atras_de_rectoria_2_features.csv
# Processing 23,327 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23327, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_atras_de_rectoria_33_features.csv
# Processing 23,333 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23333, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_atras_de_rectoria_46_features.csv
# Processing 23,336 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23336, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_atras_de_rectoria_48_features.csv
# Processing 23,324 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23324, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_atras_de_rectoria_54_features.csv
# Processing 23,331 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23331, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_atras_de_rectoria_6_features.csv
# Processing 23,336 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23336, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_atras_de_rectoria_61_features.csv
# Processing 23,335 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23335, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_atras_de_rectoria_70_features.csv
# Processing 23,328 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23328, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_atras_de_rectoria_72_features.csv
# Processing 20,871 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20871, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_cancha_de_futbol_10_features.csv
# Processing 20,877 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20877, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_cancha_de_futbol_18_features.csv
# Processing 20,877 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20877, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_cancha_de_futbol_2_features.csv
# Processing 20,870 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20870, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_cancha_de_futbol_20_features.csv
# Processing 20,867 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20867, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_cancha_de_futbol_24_features.csv
# Processing 20,872 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20872, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_cancha_de_futbol_27_features.csv
# Processing 20,871 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20871, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_cancha_de_futbol_32_features.csv
# Processing 20,865 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20865, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_cancha_de_futbol_35_features.csv
# Processing 20,868 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20868, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_cancha_de_futbol_42_features.csv
# Processing 20,865 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20865, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_cancha_de_futbol_62_features.csv
# Processing 22,643 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22643, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_dropOff_2_21_features.csv
# Processing 22,638 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22638, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_dropOff_2_26_features.csv
# Processing 22,645 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22645, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_dropOff_2_27_features.csv
# Processing 22,658 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22658, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_dropOff_2_28_features.csv
# Processing 22,645 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22645, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_dropOff_2_31_features.csv
# Processing 22,645 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22645, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_dropOff_2_36_features.csv
# Processing 22,624 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22624, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_dropOff_2_43_features.csv
# Processing 22,644 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22644, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_dropOff_2_46_features.csv
# Processing 22,646 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22646, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_dropOff_2_49_features.csv
# Processing 22,637 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22637, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_dropOff_2_55_features.csv
# Processing 21,750 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21750, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_dropOff_34_features.csv
# Processing 21,757 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21757, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_dropOff_37_features.csv
# Processing 21,758 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21758, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_dropOff_42_features.csv
# Processing 21,760 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21760, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_dropOff_45_features.csv
# Processing 21,746 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21746, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_dropOff_52_features.csv
# Processing 21,750 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21750, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_dropOff_59_features.csv
# Processing 21,741 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21741, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_dropOff_63_features.csv
# Processing 21,758 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21758, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_dropOff_64_features.csv
# Processing 21,754 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21754, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_dropOff_66_features.csv
# Processing 21,746 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21746, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_dropOff_70_features.csv
# Processing 23,157 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23157, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_escaleras_pasillocrgs_estacionamiento_10_features.csv
# Processing 23,158 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23158, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_escaleras_pasillocrgs_estacionamiento_16_features.csv
# Processing 23,166 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23166, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_escaleras_pasillocrgs_estacionamiento_25_features.csv
# Processing 23,155 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23155, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_escaleras_pasillocrgs_estacionamiento_32_features.csv
# Processing 23,153 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23153, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_escaleras_pasillocrgs_estacionamiento_45_features.csv
# Processing 23,169 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23169, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_escaleras_pasillocrgs_estacionamiento_5_features.csv
# Processing 23,145 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23145, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_escaleras_pasillocrgs_estacionamiento_54_features.csv
# Processing 23,149 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23149, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_escaleras_pasillocrgs_estacionamiento_56_features.csv
# Processing 23,145 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23145, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_escaleras_pasillocrgs_estacionamiento_64_features.csv
# Processing 23,151 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23151, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_escaleras_pasillocrgs_estacionamiento_67_features.csv
# Processing 18,944 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (18944, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_rectoria_otravez_12_features.csv
# Processing 18,954 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (18954, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_rectoria_otravez_21_features.csv
# Processing 18,952 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (18952, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_rectoria_otravez_31_features.csv
# Processing 18,948 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (18948, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_rectoria_otravez_32_features.csv
# Processing 18,959 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (18959, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_rectoria_otravez_40_features.csv
# Processing 18,942 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (18942, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_rectoria_otravez_50_features.csv
# Processing 18,943 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (18943, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_rectoria_otravez_54_features.csv
# Processing 18,945 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (18945, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_rectoria_otravez_70_features.csv
# Processing 18,941 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (18941, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_rectoria_otravez_75_features.csv
# Processing 18,947 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (18947, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\adoquin_rectoria_otravez_9_features.csv
# Processing 21,104 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21104, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_adoquin_12_features.csv
# Processing 21,100 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21100, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_adoquin_15_features.csv
# Processing 21,105 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21105, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_adoquin_27_features.csv
# Processing 21,098 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21098, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_adoquin_31_features.csv
# Processing 21,100 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21100, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_adoquin_35_features.csv
# Processing 21,104 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21104, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_adoquin_39_features.csv
# Processing 21,106 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21106, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_adoquin_41_features.csv
# Processing 21,106 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21106, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_adoquin_53_features.csv
# Processing 21,093 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21093, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_adoquin_6_features.csv
# Processing 21,112 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21112, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_adoquin_65_features.csv
# Processing 23,097 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23097, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_14_features.csv
# Processing 23,103 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23103, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_2_features.csv
# Processing 23,097 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23097, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_28_features.csv
# Processing 23,099 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23099, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_29_features.csv
# Processing 22,765 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22765, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_2_sombra_11_features.csv
# Processing 22,764 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22764, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_2_sombra_28_features.csv
# Processing 22,760 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22760, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_2_sombra_4_features.csv
# Processing 22,755 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22755, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_2_sombra_41_features.csv
# Processing 22,756 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22756, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_2_sombra_42_features.csv
# Processing 22,756 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22756, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_2_sombra_70_features.csv
# Processing 22,758 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22758, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_2_sombra_72_features.csv
# Processing 22,761 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22761, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_2_sombra_73_features.csv
# Processing 22,756 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22756, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_2_sombra_77_features.csv
# Processing 22,760 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22760, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_2_sombra_8_features.csv
# Processing 23,100 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23100, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_32_features.csv
# Processing 23,317 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23317, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_3_sombraysol_10_features.csv
# Processing 23,313 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23313, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_3_sombraysol_19_features.csv
# Processing 23,322 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23322, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_3_sombraysol_2_features.csv
# Processing 23,325 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23325, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_3_sombraysol_32_features.csv
# Processing 23,323 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23323, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_3_sombraysol_34_features.csv
# Processing 23,320 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23320, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_3_sombraysol_39_features.csv
# Processing 23,322 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23322, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_3_sombraysol_46_features.csv
# Processing 23,320 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23320, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_3_sombraysol_57_features.csv
# Processing 23,324 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23324, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_3_sombraysol_64_features.csv
# Processing 23,322 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23322, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_3_sombraysol_67_features.csv
# Processing 23,107 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23107, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_41_features.csv
# Processing 23,088 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23088, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_5_features.csv
# Processing 23,098 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23098, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_51_features.csv
# Processing 23,102 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23102, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_6_features.csv
# Processing 23,093 points with label 'adoquin'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23093, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\adoquin\crgs_atras_adoquin_69_features.csv
# Completed adoquin: 100 files processed
#
#
# ======================================================================
#
# Folder Name: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Preprocessing_10\asfalto
#
# Found a total of 100 CSV files in the directory.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Processing 20,980 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20980, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_biblio_15_features.csv
# Processing 20,977 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20977, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_biblio_24_features.csv
# Processing 20,985 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20985, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_biblio_28_features.csv
# Processing 21,264 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21264, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_biblio_2_24_features.csv
# Processing 21,264 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21264, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_biblio_2_25_features.csv
# Processing 21,265 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21265, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_biblio_2_29_features.csv
# Processing 21,267 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21267, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_biblio_2_3_features.csv
# Processing 21,290 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21290, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_biblio_2_31_features.csv
# Processing 21,273 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21273, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_biblio_2_33_features.csv
# Processing 21,271 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21271, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_biblio_2_35_features.csv
# Processing 21,267 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21267, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_biblio_2_62_features.csv
# Processing 21,260 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21260, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_biblio_2_65_features.csv
# Processing 21,265 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (21265, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_biblio_2_7_features.csv
# Processing 20,967 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20967, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_biblio_31_features.csv
# Processing 20,966 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20966, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_biblio_39_features.csv
# Processing 20,974 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20974, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_biblio_43_features.csv
# Processing 20,985 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20985, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_biblio_5_features.csv
# Processing 20,964 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20964, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_biblio_57_features.csv
# Processing 20,974 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20974, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_biblio_61_features.csv
# Processing 20,954 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20954, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_biblio_69_features.csv
# Processing 20,024 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20024, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_canchafutbol_22_features.csv
# Processing 20,034 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20034, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_canchafutbol_29_features.csv
# Processing 20,033 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20033, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_canchafutbol_38_features.csv
# Processing 20,024 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20024, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_canchafutbol_42_features.csv
# Processing 20,016 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20016, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_canchafutbol_49_features.csv
# Processing 20,029 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20029, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_canchafutbol_55_features.csv
# Processing 20,035 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20035, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_canchafutbol_60_features.csv
# Processing 20,034 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20034, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_canchafutbol_64_features.csv
# Processing 20,018 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20018, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_canchafutbol_69_features.csv
# Processing 20,032 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20032, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_canchafutbol_8_features.csv
# Processing 20,982 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20982, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_garajes_17_features.csv
# Processing 20,967 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20967, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_garajes_28_features.csv
# Processing 20,960 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20960, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_garajes_33_features.csv
# Processing 20,967 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20967, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_garajes_40_features.csv
# Processing 20,964 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20964, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_garajes_41_features.csv
# Processing 20,965 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20965, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_garajes_42_features.csv
# Processing 20,961 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20961, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_garajes_53_features.csv
# Processing 20,953 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20953, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_garajes_57_features.csv
# Processing 20,957 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20957, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_garajes_58_features.csv
# Processing 20,958 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (20958, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_garajes_70_features.csv
# Processing 22,728 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22728, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_profes_0_features.csv
# Processing 22,730 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22730, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_profes_11_features.csv
# Processing 22,734 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22734, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_profes_22_features.csv
# Processing 23,026 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23026, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_profes_2_0_features.csv
# Processing 23,036 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23036, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_profes_2_10_features.csv
# Processing 23,028 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23028, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_profes_2_17_features.csv
# Processing 23,032 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23032, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_profes_2_44_features.csv
# Processing 23,018 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23018, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_profes_2_48_features.csv
# Processing 23,024 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23024, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_profes_2_50_features.csv
# Processing 23,027 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23027, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_profes_2_61_features.csv
# Processing 23,033 points with label 'asfalto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23033, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\asfalto\asfalto_estacionamiento_profes_2_64_features.csv
# ...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23721, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\crgs_pasto_1_59_features.csv
# Processing 23,717 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23717, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\crgs_pasto_1_67_features.csv
# Processing 23,719 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23719, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\crgs_pasto_1_72_features.csv
# Processing 22,559 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22559, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\crgs_pasto_2_17_features.csv
# Processing 22,564 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22564, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\crgs_pasto_2_18_features.csv
# Processing 22,550 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22550, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\crgs_pasto_2_21_features.csv
# Processing 22,554 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22554, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\crgs_pasto_2_25_features.csv
# Processing 22,558 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22558, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\crgs_pasto_2_29_features.csv
# Processing 22,542 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22542, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\crgs_pasto_2_38_features.csv
# Processing 22,554 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22554, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\crgs_pasto_2_50_features.csv
# Processing 22,547 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22547, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\crgs_pasto_2_52_features.csv
# Processing 22,548 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22548, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\crgs_pasto_2_65_features.csv
# Processing 22,552 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22552, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\crgs_pasto_2_8_features.csv
# Processing 23,843 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23843, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\entre_ccu_y_rectoria_19_features.csv
# Processing 23,842 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23842, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\entre_ccu_y_rectoria_20_features.csv
# Processing 23,845 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23845, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\entre_ccu_y_rectoria_22_features.csv
# Processing 23,834 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23834, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\entre_ccu_y_rectoria_25_features.csv
# Processing 23,834 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23834, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\entre_ccu_y_rectoria_39_features.csv
# Processing 23,839 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23839, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\entre_ccu_y_rectoria_44_features.csv
# Processing 23,840 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23840, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\entre_ccu_y_rectoria_48_features.csv
# Processing 23,841 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23841, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\entre_ccu_y_rectoria_52_features.csv
# Processing 23,833 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23833, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\entre_ccu_y_rectoria_55_features.csv
# Processing 23,847 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23847, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\entre_ccu_y_rectoria_61_features.csv
# Processing 24,882 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (24882, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\jardin_abajo_papas_1_12_features.csv
# Processing 24,881 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (24881, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\jardin_abajo_papas_1_19_features.csv
# Processing 24,876 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (24876, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\jardin_abajo_papas_1_20_features.csv
# Processing 24,889 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (24889, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\jardin_abajo_papas_1_22_features.csv
# Processing 24,883 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (24883, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\jardin_abajo_papas_1_30_features.csv
# Processing 24,886 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (24886, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\jardin_abajo_papas_1_42_features.csv
# Processing 24,884 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (24884, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\jardin_abajo_papas_1_57_features.csv
# Processing 24,886 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (24886, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\jardin_abajo_papas_1_62_features.csv
# Processing 24,879 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (24879, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\jardin_abajo_papas_1_65_features.csv
# Processing 24,884 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (24884, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\jardin_abajo_papas_1_66_features.csv
# Processing 23,210 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23210, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\pasto_rectoria_1_0_features.csv
# Processing 23,190 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23190, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\pasto_rectoria_1_2_features.csv
# Processing 23,184 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23184, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\pasto_rectoria_1_33_features.csv
# Processing 23,187 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23187, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\pasto_rectoria_1_36_features.csv
# Processing 23,194 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23194, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\pasto_rectoria_1_37_features.csv
# Processing 23,193 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23193, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\pasto_rectoria_1_43_features.csv
# Processing 23,197 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23197, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\pasto_rectoria_1_45_features.csv
# Processing 23,193 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23193, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\pasto_rectoria_1_56_features.csv
# Processing 23,191 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23191, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\pasto_rectoria_1_60_features.csv
# Processing 23,188 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (23188, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\pasto_rectoria_1_71_features.csv
# Processing 22,015 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22015, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\pasto_rectoria_2_19_features.csv
# Processing 22,009 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22009, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\pasto_rectoria_2_23_features.csv
# Processing 22,020 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22020, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\pasto_rectoria_2_28_features.csv
# Processing 22,024 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22024, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\pasto_rectoria_2_38_features.csv
# Processing 22,012 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22012, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\pasto_rectoria_2_39_features.csv
# Processing 22,010 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22010, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\pasto_rectoria_2_40_features.csv
# Processing 22,026 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22026, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\pasto_rectoria_2_45_features.csv
# Processing 22,023 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22023, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\pasto_rectoria_2_51_features.csv
# Processing 22,021 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22021, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\pasto_rectoria_2_60_features.csv
# Processing 22,021 points with label 'pasto'...
# Building NN tree (k=10...
# Finding neighbors for all points...
# Computing features (vectorized)...
#
# Processing complete: (22021, 9)
# Saved to: C:\Users\USER\PEF\Terrain-Traversability-Analysis\Vectorized_Features_K10\pasto\pasto_rectoria_2_66_features.csv
# Completed pasto: 100 files processed
#
#
# ======================================================================
# All classes processed successfully.
